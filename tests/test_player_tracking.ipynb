# %%
import os
import sys
import mido
import time
import numpy as np

project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.utils import basename
from src.ml.specdiff.model import SpectrogramDiffusion, DEFAULT_CONFIG

# %%
tmp_dir = "outputs/embeddings"
midi_port = "LPK25"
DEFAULT_CONFIG["device"] = "cpu"
DEFAULT_CONFIG["encoder_weights_path"] = (
    "/Users/finlay/Documents/Programming/disklavier/src/ml/specdiff/note_encoder.bin"
)
model = SpectrogramDiffusion(DEFAULT_CONFIG, verbose=False)
record_length = 5
difference_threshold = 2.5
# Out:
# 04-29 14:52:32.075037 spcdif: initializing spectrogram diffusion model                                  ]8;id=101267;file:///Users/finlay/Documents/Programming/disklavier/src/ml/specdiff/model.py\model.py]8;;\:]8;id=651920;file:///Users/finlay/Documents/Programming/disklavier/src/ml/specdiff/model.py#56\56]8;;\
# 04-29 14:52:32.557512 spcdif: model initialization complete                                             ]8;id=714296;file:///Users/finlay/Documents/Programming/disklavier/src/ml/specdiff/model.py\model.py]8;;\:]8;id=437373;file:///Users/finlay/Documents/Programming/disklavier/src/ml/specdiff/model.py#87\87]8;;\

# %%
master_midi = mido.MidiFile(ticks_per_beat=220)
master_midi.add_track()

midi = mido.MidiFile(ticks_per_beat=220)
track = mido.MidiTrack()
track.name = "player_recording_00"

first_msg = True
num_embeddings = 0
last_embedding = None
embeddings = np.zeros((10, 768))  # only store last 10 embeddings
print("waiting for first note")
try:
    with mido.open_input(midi_port) as inport:
        for msg in inport:
            # init time tracking
            if first_msg:
                first_msg = False
                start_time = time.time()
                last_note_time = start_time
                now = start_time
                print("starting recording at", start_time)
            else:
                now = time.time()

            # update msg time
            msg.time = mido.second2tick(now - last_note_time, 220, mido.bpm2tempo(120))
            last_note_time = now
            track.append(msg)
            master_midi.tracks[0].append(msg)

            # save and embed when recording is done
            if now - start_time > record_length:
                # print(track)
                midi.tracks.append(track)
                filename = os.path.join(
                    tmp_dir, f"player_recording_{num_embeddings:02d}.mid"
                )
                midi.save(filename)

                print(f"total time is {now - start_time}")
                print(f"embedding {num_embeddings}")
                embedding = model.embed(filename)
                embeddings[num_embeddings % 10] = embedding
                print("embedding complete")

                if last_embedding is not None:
                    # calculate magnitude of difference between last embedding and current embedding
                    diff_mag = np.linalg.norm(last_embedding - embedding)
                    print(f"Difference magnitude: {diff_mag}")

                # reset tracking
                midi = mido.MidiFile(ticks_per_beat=220)
                track = mido.MidiTrack()
                track.name = f"player_recording_{num_embeddings}"
                last_embedding = embedding
                start_time = time.time()
                num_embeddings += 1
except Exception as e:
    print(e)
# Out:
# waiting for first note
# starting recording at 1745949156.256033
# total time is 5.839620113372803
# embedding 0
# /var/folders/8c/sxhlb80n0c93ft54s3hhn5yw0000gn/T/ipykernel_9958/2839614638.py:44: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   embeddings[num_embeddings % 10] = embedding
# embedding complete
# total time is 5.233791828155518
# embedding 1
# embedding complete
# Difference magnitude: 2.4894564151763916
# total time is 5.038543701171875
# embedding 2
# embedding complete
# Difference magnitude: 2.8305609226226807
# total time is 5.088855028152466
# embedding 3
# embedding complete
# Difference magnitude: 2.5169053077697754
# total time is 6.6554319858551025
# embedding 4
# embedding complete
# Difference magnitude: 2.1539387702941895
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 15
#      13 try:
#      14     with mido.open_input(midi_port) as inport:
# ---> 15         for msg in inport:
#      16             # init time tracking
#      17             if first_msg:
#      18                 first_msg = False
#
# File ~/miniconda3/envs/midi-ml/lib/python3.12/site-packages/mido/ports.py:243, in BaseInput.__iter__(self)
#     241 while True:
#     242     try:
# --> 243         yield self.receive()
#     244     except OSError:
#     245         if self.closed:
#     246             # The port closed before or inside receive().
#     247             # (This makes the assumption that this is the reason,
#     248             # at the risk of masking other errors.)
#
# File ~/miniconda3/envs/midi-ml/lib/python3.12/site-packages/mido/backends/rtmidi.py:152, in Input.receive(self, block)
#     150 def receive(self, block=True):
#     151     if block:
# --> 152         return self._queue.get()
#     153     else:
#     154         return self._queue.poll()
#
# File ~/miniconda3/envs/midi-ml/lib/python3.12/site-packages/mido/backends/_parser_queue.py:43, in ParserQueue.get(self)
#      42 def get(self):
# ---> 43     return self._queue.get()
#
# File ~/miniconda3/envs/midi-ml/lib/python3.12/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File ~/miniconda3/envs/midi-ml/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
master_midi.save(os.path.join(tmp_dir, "master_midi.mid"))
master_midi.print_tracks()
# Out:
# === Track 0
# Message('note_on', channel=0, note=40, velocity=89, time=0)
# Message('note_off', channel=0, note=40, velocity=127, time=100)
# Message('note_on', channel=0, note=41, velocity=105, time=42)
# Message('note_off', channel=0, note=41, velocity=127, time=95)
# Message('note_on', channel=0, note=44, velocity=119, time=45)
# Message('note_off', channel=0, note=44, velocity=127, time=86)
# Message('note_on', channel=0, note=46, velocity=109, time=70)
# Message('note_off', channel=0, note=46, velocity=127, time=99)
# Message('note_on', channel=0, note=48, velocity=113, time=51)
# Message('note_off', channel=0, note=48, velocity=127, time=109)
# Message('note_on', channel=0, note=44, velocity=109, time=27)
# Message('note_off', channel=0, note=44, velocity=127, time=79)
# Message('note_on', channel=0, note=48, velocity=123, time=75)
# Message('note_off', channel=0, note=48, velocity=127, time=292)
# Message('note_on', channel=0, note=47, velocity=117, time=29)
# Message('note_on', channel=0, note=44, velocity=1, time=0)
# Message('note_off', channel=0, note=44, velocity=127, time=22)
# Message('note_off', channel=0, note=47, velocity=127, time=105)
# Message('note_on', channel=0, note=43, velocity=84, time=30)
# Message('note_off', channel=0, note=43, velocity=127, time=89)
# Message('note_on', channel=0, note=47, velocity=122, time=68)
# Message('note_on', channel=0, note=46, velocity=113, time=276)
# Message('note_off', channel=0, note=47, velocity=127, time=15)
# Message('note_off', channel=0, note=46, velocity=127, time=85)
# Message('note_on', channel=0, note=42, velocity=122, time=36)
# Message('note_off', channel=0, note=42, velocity=127, time=90)
# Message('note_on', channel=0, note=46, velocity=124, time=63)
# Message('note_on', channel=0, note=40, velocity=88, time=492)
# Message('note_off', channel=0, note=46, velocity=127, time=688)
# Message('note_off', channel=0, note=40, velocity=127, time=0)
# Message('note_on', channel=0, note=41, velocity=110, time=0)
# Message('note_off', channel=0, note=41, velocity=127, time=0)
# Message('note_on', channel=0, note=41, velocity=99, time=0)
# Message('note_off', channel=0, note=41, velocity=127, time=0)
# Message('note_on', channel=0, note=40, velocity=117, time=0)
# Message('note_off', channel=0, note=40, velocity=127, time=0)
# Message('note_on', channel=0, note=41, velocity=118, time=24)
# Message('note_off', channel=0, note=41, velocity=127, time=158)
# Message('note_on', channel=0, note=41, velocity=113, time=92)
# Message('note_off', channel=0, note=41, velocity=127, time=137)
# Message('note_on', channel=0, note=40, velocity=116, time=4)
# Message('note_off', channel=0, note=40, velocity=127, time=120)
# Message('note_on', channel=0, note=41, velocity=99, time=16)
# Message('note_off', channel=0, note=41, velocity=127, time=189)
# Message('note_on', channel=0, note=41, velocity=108, time=76)
# Message('note_on', channel=0, note=40, velocity=113, time=129)
# Message('note_off', channel=0, note=41, velocity=127, time=11)
# Message('note_on', channel=0, note=41, velocity=122, time=124)
# Message('note_off', channel=0, note=40, velocity=127, time=20)
# Message('note_off', channel=0, note=41, velocity=127, time=130)
# Message('note_on', channel=0, note=41, velocity=102, time=107)
# Message('note_on', channel=0, note=40, velocity=116, time=137)
# Message('note_off', channel=0, note=41, velocity=127, time=13)
# Message('note_on', channel=0, note=41, velocity=119, time=111)
# Message('note_off', channel=0, note=40, velocity=127, time=41)
# Message('note_off', channel=0, note=41, velocity=127, time=114)
# Message('note_on', channel=0, note=41, velocity=103, time=96)
# Message('note_on', channel=0, note=40, velocity=105, time=144)
# Message('note_off', channel=0, note=41, velocity=127, time=16)
# Message('note_on', channel=0, note=41, velocity=119, time=114)
# Message('note_off', channel=0, note=40, velocity=127, time=41)
# Message('note_off', channel=0, note=41, velocity=127, time=141)
# Message('note_on', channel=0, note=41, velocity=117, time=677)
# Message('note_on', channel=0, note=40, velocity=108, time=0)
# Message('note_off', channel=0, note=41, velocity=127, time=0)
# Message('note_on', channel=0, note=41, velocity=115, time=0)
# Message('note_off', channel=0, note=40, velocity=127, time=0)
# Message('note_off', channel=0, note=41, velocity=127, time=0)
# Message('note_on', channel=0, note=41, velocity=111, time=0)
# Message('note_on', channel=0, note=40, velocity=116, time=54)
# Message('note_off', channel=0, note=41, velocity=127, time=22)
# Message('note_on', channel=0, note=41, velocity=118, time=100)
# Message('note_off', channel=0, note=40, velocity=127, time=31)
# Message('note_off', channel=0, note=41, velocity=127, time=56)
# Message('note_on', channel=0, note=71, velocity=119, time=211)
# Message('note_off', channel=0, note=71, velocity=127, time=80)
# Message('note_on', channel=0, note=69, velocity=121, time=15)
# Message('note_on', channel=0, note=71, velocity=109, time=103)
# Message('note_off', channel=0, note=69, velocity=127, time=7)
# Message('note_on', channel=0, note=69, velocity=118, time=57)
# Message('note_off', channel=0, note=71, velocity=127, time=11)
# Message('note_off', channel=0, note=69, velocity=127, time=41)
# Message('note_on', channel=0, note=71, velocity=103, time=25)
# Message('note_on', channel=0, note=69, velocity=96, time=48)
# Message('note_off', channel=0, note=71, velocity=127, time=86)
# Message('note_on', channel=0, note=67, velocity=80, time=1)
# Message('note_off', channel=0, note=69, velocity=127, time=21)
# Message('note_on', channel=0, note=69, velocity=119, time=101)
# Message('note_off', channel=0, note=67, velocity=127, time=20)
# Message('note_on', channel=0, note=71, velocity=100, time=41)
# Message('note_off', channel=0, note=69, velocity=127, time=10)
# Message('note_on', channel=0, note=69, velocity=114, time=53)
# Message('note_off', channel=0, note=71, velocity=127, time=39)
# Message('note_on', channel=0, note=67, velocity=85, time=26)
# Message('note_off', channel=0, note=69, velocity=127, time=31)
# Message('note_on', channel=0, note=71, velocity=107, time=54)
# Message('note_off', channel=0, note=67, velocity=127, time=18)
# Message('note_on', channel=0, note=69, velocity=91, time=40)
# Message('note_off', channel=0, note=71, velocity=127, time=36)
# Message('note_on', channel=0, note=67, velocity=82, time=50)
# Message('note_off', channel=0, note=69, velocity=127, time=21)
# Message('note_on', channel=0, note=69, velocity=95, time=74)
# Message('note_off', channel=0, note=67, velocity=127, time=14)
# Message('note_on', channel=0, note=67, velocity=103, time=75)
# Message('note_off', channel=0, note=69, velocity=127, time=36)
# Message('note_on', channel=0, note=53, velocity=106, time=86)
# Message('note_off', channel=0, note=67, velocity=127, time=14)
# Message('note_on', channel=0, note=58, velocity=116, time=92)
# Message('note_off', channel=0, note=53, velocity=127, time=29)
# Message('note_on', channel=0, note=60, velocity=97, time=77)
# Message('note_off', channel=0, note=58, velocity=127, time=37)
# Message('note_on', channel=0, note=53, velocity=107, time=69)
# Message('note_off', channel=0, note=60, velocity=127, time=31)
# Message('note_on', channel=0, note=58, velocity=107, time=73)
# Message('note_off', channel=0, note=53, velocity=127, time=690)
# Message('note_on', channel=0, note=60, velocity=103, time=0)
# Message('note_off', channel=0, note=58, velocity=127, time=0)
# Message('note_on', channel=0, note=53, velocity=104, time=0)
# Message('note_off', channel=0, note=60, velocity=127, time=0)
# Message('note_on', channel=0, note=58, velocity=101, time=0)
# Message('note_off', channel=0, note=53, velocity=127, time=0)
# Message('note_on', channel=0, note=60, velocity=107, time=0)
# Message('note_off', channel=0, note=58, velocity=127, time=0)
# Message('note_on', channel=0, note=53, velocity=111, time=0)
# Message('note_off', channel=0, note=60, velocity=127, time=0)
# Message('note_on', channel=0, note=58, velocity=114, time=0)
# Message('note_off', channel=0, note=53, velocity=127, time=0)
# Message('note_on', channel=0, note=60, velocity=101, time=65)
# Message('note_off', channel=0, note=58, velocity=127, time=20)
# Message('note_on', channel=0, note=53, velocity=87, time=81)
# Message('note_off', channel=0, note=60, velocity=127, time=41)
# Message('note_on', channel=0, note=58, velocity=96, time=60)
# Message('note_off', channel=0, note=53, velocity=127, time=62)
# Message('note_on', channel=0, note=62, velocity=63, time=51)
# Message('note_off', channel=0, note=58, velocity=127, time=19)
# Message('note_on', channel=0, note=53, velocity=108, time=86)
# Message('note_off', channel=0, note=62, velocity=127, time=46)
# Message('note_on', channel=0, note=58, velocity=91, time=56)
# Message('note_off', channel=0, note=53, velocity=127, time=70)
# Message('note_on', channel=0, note=62, velocity=81, time=42)
# Message('note_off', channel=0, note=58, velocity=127, time=33)
# Message('note_on', channel=0, note=53, velocity=106, time=94)
# Message('note_off', channel=0, note=62, velocity=127, time=49)
# Message('note_on', channel=0, note=58, velocity=103, time=63)
# Message('note_off', channel=0, note=53, velocity=127, time=54)
# Message('note_on', channel=0, note=62, velocity=101, time=63)
# Message('note_off', channel=0, note=58, velocity=127, time=18)
# Message('note_on', channel=0, note=58, velocity=116, time=99)
# Message('note_off', channel=0, note=62, velocity=127, time=33)
# Message('note_on', channel=0, note=53, velocity=97, time=89)
# Message('note_off', channel=0, note=58, velocity=127, time=54)
# Message('note_on', channel=0, note=58, velocity=114, time=63)
# Message('note_off', channel=0, note=53, velocity=127, time=53)
# Message('note_on', channel=0, note=62, velocity=99, time=69)
# Message('note_off', channel=0, note=58, velocity=127, time=28)
# Message('note_on', channel=0, note=58, velocity=112, time=86)
# Message('note_off', channel=0, note=62, velocity=127, time=38)
# Message('note_on', channel=0, note=52, velocity=98, time=76)
# Message('note_off', channel=0, note=58, velocity=127, time=23)
# Message('note_on', channel=0, note=58, velocity=96, time=90)
# Message('note_off', channel=0, note=52, velocity=127, time=71)
# Message('note_on', channel=0, note=62, velocity=93, time=65)
# Message('note_off', channel=0, note=58, velocity=127, time=28)
# Message('note_on', channel=0, note=52, velocity=92, time=89)
# Message('note_off', channel=0, note=62, velocity=127, time=43)
# Message('note_on', channel=0, note=58, velocity=105, time=69)
# Message('note_off', channel=0, note=52, velocity=127, time=685)
# Message('note_on', channel=0, note=62, velocity=79, time=0)
# Message('note_off', channel=0, note=58, velocity=127, time=0)
# Message('note_on', channel=0, note=52, velocity=108, time=0)
# Message('note_off', channel=0, note=62, velocity=127, time=0)
# Message('note_on', channel=0, note=58, velocity=102, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=0)
# Message('note_on', channel=0, note=62, velocity=88, time=0)
# Message('note_off', channel=0, note=58, velocity=127, time=0)
# Message('note_on', channel=0, note=52, velocity=98, time=0)
# Message('note_off', channel=0, note=62, velocity=127, time=0)
# Message('note_on', channel=0, note=58, velocity=105, time=0)
# Message('note_off', channel=0, note=52, velocity=127, time=42)
# Message('note_on', channel=0, note=62, velocity=92, time=64)
# Message('note_off', channel=0, note=58, velocity=127, time=30)
# Message('note_on', channel=0, note=52, velocity=110, time=77)
# Message('note_off', channel=0, note=62, velocity=127, time=41)
# Message('note_on', channel=0, note=57, velocity=107, time=75)
# Message('note_off', channel=0, note=52, velocity=127, time=53)
# Message('note_on', channel=0, note=60, velocity=105, time=54)
# Message('note_off', channel=0, note=57, velocity=127, time=16)
# Message('note_on', channel=0, note=52, velocity=105, time=100)
# Message('note_off', channel=0, note=60, velocity=127, time=36)
# Message('note_on', channel=0, note=57, velocity=102, time=89)
# Message('note_off', channel=0, note=52, velocity=127, time=54)
# Message('note_on', channel=0, note=60, velocity=102, time=72)
# Message('note_off', channel=0, note=57, velocity=127, time=29)
# Message('note_on', channel=0, note=52, velocity=108, time=88)
# Message('note_off', channel=0, note=60, velocity=127, time=64)
# Message('note_on', channel=0, note=57, velocity=116, time=45)
# Message('note_off', channel=0, note=52, velocity=127, time=61)
# Message('note_on', channel=0, note=60, velocity=87, time=71)
# Message('note_off', channel=0, note=57, velocity=127, time=36)
# Message('note_on', channel=0, note=52, velocity=114, time=92)
# Message('note_off', channel=0, note=60, velocity=127, time=73)
# Message('note_on', channel=0, note=57, velocity=106, time=115)
# Message('note_off', channel=0, note=52, velocity=127, time=176)
# Message('note_on', channel=0, note=60, velocity=109, time=14)
# Message('note_off', channel=0, note=57, velocity=127, time=50)
# Message('note_off', channel=0, note=60, velocity=127, time=1212)
# Message('note_on', channel=0, note=62, velocity=121, time=1620)
# Message('note_on', channel=0, note=64, velocity=120, time=1)
# Message('note_off', channel=0, note=64, velocity=127, time=52)
# Message('note_off', channel=0, note=62, velocity=127, time=3)
