# %%
import threading
import mido

import midi_loader as ml
import midi_playback as mp

# %%
def show_tree(tree, total_width=60, fill=" "):
    import math
    from io import StringIO

    output = StringIO()
    last_row = -1
    for i, n in enumerate(tree):
        if i:
            row = int(math.floor(math.log(i + 1, 2)))
            if row > 3:
                break
        else:
            row = 0
        if row != last_row:
            output.write("\n")
        columns = 2**row
        col_width = int(math.floor((total_width * 1.0) / columns))
        output.write(str(f"{n[1].global_ticks:02d}").center(col_width, fill))
        last_row = row
    print(output.getvalue())
    print("-" * total_width)
    return

# %%
def save_queue_to_midi(scheduler, output_filename):
    from mido import MidiTrack, MidiFile

    """Reads the event queue from the scheduler and saves it as a MIDI file."""
    # Create a new MIDI file and a single track
    midi = MidiFile()
    track = MidiTrack()
    midi.tracks.append(track)
    track.append(mido.MetaMessage("set_tempo", tempo=scheduler.tempo, time=0))
    last_event_ticks = 0

    # Sort the queue to ensure events are in the correct order
    with scheduler.queue_lock:
        sorted_events = sorted(scheduler.event_queue)

    for event_ticks, midi_event in sorted_events:
        ticks_delta = event_ticks - last_event_ticks
        last_event_ticks = event_ticks

        # Create a new message with the correct time delta
        # event_data = midi_event.msg.copy(time=ticks_delta)
        track.append(midi_event.msg)

    # Save the MIDI file
    midi.save(output_filename)
    print(f"MIDI file saved as {output_filename}")

# %%
bpm = 60

print(f"segment separation will be {8 * (60 / bpm)} seconds")

loader = ml.MidiLoader("data/datasets/test/synthetic", bpm)
loader.load_midi_files()
scheduler = mp.PlaybackScheduler(bpm, "Disklavier")

scheduler.start_playback()


# Schedule the files in a separate thread
def scheduling_thread():
    start_ticks = mido.second2tick(3.0, loader.ticks_per_beat, mido.bpm2tempo(bpm))
    for midi_file in loader.midi_files:
        scheduler.schedule_events(midi_file, start_ticks)
        start_ticks += loader.duration_t - loader.ticks_per_beat
    save_queue_to_midi(scheduler, "outputs/output.mid")
    show_tree(scheduler.event_queue)


threading.Thread(target=scheduling_thread, name="scheduler").start()
# Out:
# segment separation will be 8.0 seconds
# segments have 96 tpb and duration 864 ticks
# loaded 20 files
# scheduling baba-060-02_0005-0011	at 003.000s (288 ticks)
# sleeping for 3.91 seconds (4.00s - 0.09s)
# scheduling bbbb-060-01_0005-0011	at 011.000s (1056 ticks)
# scheduling c4v100-060-03_0000-0005	at 019.000s (1824 ticks)
# scheduling c4v97-060-03_0005-0011	at 027.000s (2592 ticks)
# scheduling cascas-060-02_0000-0005	at 035.000s (3360 ticks)
# scheduling cascd-060-02_0000-0005	at 043.000s (4128 ticks)
# scheduling cascd-060-02_0005-0011	at 051.000s (4896 ticks)
# scheduling cccc-060-01_0000-0005	at 059.000s (5664 ticks)
# scheduling leadtest-060-03_0000-0005	at 067.000s (6432 ticks)
# scheduling trailtest-060-03_0005-0011	at 075.000s (7200 ticks)
# scheduling baba-060-02_0005-0011	at 083.000s (7968 ticks)
# scheduling bbbb-060-01_0005-0011	at 091.000s (8736 ticks)
# scheduling c4v100-060-03_0000-0005	at 099.000s (9504 ticks)
# scheduling c4v97-060-03_0005-0011	at 107.000s (10272 ticks)
# scheduling cascas-060-02_0000-0005	at 115.000s (11040 ticks)
# scheduling cascd-060-02_0000-0005	at 123.000s (11808 ticks)
# scheduling cascd-060-02_0005-0011	at 131.000s (12576 ticks)
# scheduling cccc-060-01_0000-0005	at 139.000s (13344 ticks)
# scheduling leadtest-060-03_0000-0005	at 147.000s (14112 ticks)
# scheduling trailtest-060-03_0005-0011	at 155.000s (14880 ticks)
# MIDI file saved as outputs/output.mid
#
#                             264
#              288                           456
#       480            648            672            840
#    96    264    288    456    480    648    672    840
# ------------------------------------------------------------
# sleeping for 1.74 seconds (5.75s - 4.01s)
# sleeping for 0.22 seconds (6.00s - 5.78s)
# sleeping for 1.72 seconds (7.75s - 6.03s)
# sleeping for 0.24 seconds (8.00s - 7.76s)
# sleeping for 1.73 seconds (9.75s - 8.02s)
# sleeping for 0.23 seconds (10.00s - 9.77s)
# sleeping for 1.74 seconds (11.75s - 10.01s)
# sleeping for 0.23 seconds (12.00s - 11.77s)
# sleeping for 1.74 seconds (13.75s - 12.01s)
# sleeping for 0.24 seconds (14.00s - 13.76s)
# sleeping for 1.74 seconds (15.75s - 14.01s)
# sleeping for 0.24 seconds (16.00s - 15.76s)
# sleeping for 1.74 seconds (17.75s - 16.01s)
# sleeping for 0.24 seconds (18.00s - 17.76s)
# sleeping for 1.73 seconds (19.75s - 18.02s)
# sleeping for 0.23 seconds (20.00s - 19.77s)
# sleeping for 6.73 seconds (26.75s - 20.02s)
# sleeping for 1.23 seconds (28.00s - 26.77s)
# sleeping for 6.73 seconds (34.75s - 28.02s)
# sleeping for 1.23 seconds (36.00s - 34.77s)
# sleeping for 1.73 seconds (37.75s - 36.02s)
# sleeping for 0.23 seconds (38.00s - 37.77s)
# sleeping for 1.73 seconds (39.75s - 38.02s)
# sleeping for 0.23 seconds (40.00s - 39.77s)
# sleeping for 1.74 seconds (41.75s - 40.01s)
# sleeping for 0.23 seconds (42.00s - 41.77s)
# sleeping for 1.74 seconds (43.75s - 42.01s)
# sleeping for 0.23 seconds (44.00s - 43.77s)
# sleeping for 1.74 seconds (45.75s - 44.01s)
# sleeping for 0.24 seconds (46.00s - 45.76s)
# sleeping for 1.74 seconds (47.75s - 46.01s)
# sleeping for 0.24 seconds (48.00s - 47.76s)
# sleeping for 1.73 seconds (49.75s - 48.02s)
# sleeping for 0.22 seconds (50.00s - 49.78s)
# sleeping for 1.74 seconds (51.75s - 50.01s)
# sleeping for 0.24 seconds (52.00s - 51.76s)
# sleeping for 1.74 seconds (53.75s - 52.01s)
# sleeping for 0.23 seconds (54.00s - 53.77s)
# sleeping for 1.74 seconds (55.75s - 54.01s)
# sleeping for 0.24 seconds (56.00s - 55.76s)
# sleeping for 1.72 seconds (57.75s - 56.03s)
# sleeping for 0.24 seconds (58.00s - 57.76s)
# sleeping for 1.74 seconds (59.75s - 58.01s)
# sleeping for 0.24 seconds (60.00s - 59.76s)
# sleeping for 1.74 seconds (61.75s - 60.01s)
# sleeping for 0.24 seconds (62.00s - 61.76s)
# sleeping for 1.74 seconds (63.75s - 62.01s)
# sleeping for 0.24 seconds (64.00s - 63.76s)
# sleeping for 1.74 seconds (65.75s - 64.01s)
# sleeping for 0.23 seconds (66.00s - 65.77s)
# sleeping for 1.73 seconds (67.75s - 66.02s)
# sleeping for -0.02 seconds (67.75s - 67.77s)
# sleeping for 0.22 seconds (68.00s - 67.78s)
# sleeping for 0.25 seconds (68.25s - 68.00s)
# sleeping for 0.24 seconds (68.50s - 68.26s)
# sleeping for 0.24 seconds (68.75s - 68.51s)
# sleeping for 0.24 seconds (69.00s - 68.76s)
# sleeping for 0.74 seconds (69.75s - 69.01s)
# sleeping for 0.24 seconds (70.00s - 69.76s)
# sleeping for 0.23 seconds (70.25s - 70.02s)
# sleeping for 0.24 seconds (70.50s - 70.26s)
# sleeping for 0.24 seconds (70.75s - 70.51s)
# sleeping for 0.24 seconds (71.00s - 70.76s)
# sleeping for 0.74 seconds (71.75s - 71.01s)
# sleeping for 0.24 seconds (72.00s - 71.76s)
# sleeping for 0.22 seconds (72.25s - 72.03s)
# sleeping for 0.24 seconds (72.50s - 72.26s)
# sleeping for 0.23 seconds (72.75s - 72.52s)
# sleeping for 0.23 seconds (73.00s - 72.77s)
# sleeping for 0.74 seconds (73.75s - 73.01s)
# sleeping for 0.24 seconds (74.00s - 73.76s)
# sleeping for 0.24 seconds (74.25s - 74.01s)
# sleeping for 0.24 seconds (74.50s - 74.26s)
# sleeping for 0.24 seconds (74.75s - 74.51s)
# sleeping for 0.24 seconds (75.00s - 74.76s)
# sleeping for 0.74 seconds (75.75s - 75.01s)
# sleeping for 0.23 seconds (76.00s - 75.77s)
# sleeping for 0.24 seconds (76.25s - 76.01s)
# sleeping for 0.24 seconds (76.50s - 76.26s)
# sleeping for 0.24 seconds (76.75s - 76.51s)
# sleeping for 0.24 seconds (77.00s - 76.76s)
# sleeping for 0.74 seconds (77.75s - 77.01s)
# sleeping for 0.24 seconds (78.00s - 77.76s)
# sleeping for 0.23 seconds (78.25s - 78.02s)
# sleeping for 0.24 seconds (78.50s - 78.26s)
# sleeping for 0.24 seconds (78.75s - 78.51s)
# sleeping for 0.23 seconds (79.00s - 78.77s)
# sleeping for 0.73 seconds (79.75s - 79.02s)
# sleeping for 0.24 seconds (80.00s - 79.76s)
# sleeping for 0.24 seconds (80.25s - 80.01s)
# sleeping for 0.24 seconds (80.50s - 80.26s)
# sleeping for 0.24 seconds (80.75s - 80.51s)
# sleeping for 0.24 seconds (81.00s - 80.76s)
# sleeping for 0.74 seconds (81.75s - 81.01s)
# sleeping for 0.24 seconds (82.00s - 81.76s)
# sleeping for 0.24 seconds (82.25s - 82.01s)
# sleeping for 0.24 seconds (82.50s - 82.26s)
# sleeping for 0.24 seconds (82.75s - 82.51s)
# sleeping for 0.24 seconds (83.00s - 82.76s)
# sleeping for 0.24 seconds (83.25s - 83.01s)
# sleeping for 0.49 seconds (83.75s - 83.26s)
# sleeping for 0.24 seconds (84.00s - 83.76s)
# sleeping for -0.02 seconds (84.00s - 84.02s)
# sleeping for -0.03 seconds (84.00s - 84.03s)
# sleeping for 1.72 seconds (85.75s - 84.03s)
# sleeping for 0.24 seconds (86.00s - 85.76s)
# sleeping for 1.74 seconds (87.75s - 86.01s)
# sleeping for 0.24 seconds (88.00s - 87.76s)
# sleeping for 1.73 seconds (89.75s - 88.02s)
# sleeping for 0.23 seconds (90.00s - 89.77s)
# sleeping for 1.74 seconds (91.75s - 90.01s)
# sleeping for 0.23 seconds (92.00s - 91.77s)
# sleeping for 1.74 seconds (93.75s - 92.01s)
# sleeping for 0.23 seconds (94.00s - 93.77s)
# sleeping for 1.73 seconds (95.75s - 94.02s)
# sleeping for 0.23 seconds (96.00s - 95.77s)
# sleeping for 1.74 seconds (97.75s - 96.01s)
# sleeping for 0.24 seconds (98.00s - 97.76s)
# sleeping for 1.73 seconds (99.75s - 98.02s)
# sleeping for 0.23 seconds (100.00s - 99.77s)
# sleeping for 6.73 seconds (106.75s - 100.02s)
# sleeping for 1.23 seconds (108.00s - 106.77s)
# sleeping for 6.72 seconds (114.75s - 108.03s)
# sleeping for 1.24 seconds (116.00s - 114.76s)
# sleeping for 1.72 seconds (117.75s - 116.03s)
# sleeping for 0.24 seconds (118.00s - 117.76s)
# sleeping for 1.74 seconds (119.75s - 118.01s)
# sleeping for 0.24 seconds (120.00s - 119.76s)
# sleeping for 1.73 seconds (121.75s - 120.02s)
# sleeping for 0.23 seconds (122.00s - 121.77s)
# sleeping for 1.73 seconds (123.75s - 122.02s)
# sleeping for 0.23 seconds (124.00s - 123.77s)
# sleeping for 1.73 seconds (125.75s - 124.02s)
# sleeping for 0.24 seconds (126.00s - 125.76s)
# sleeping for 1.72 seconds (127.75s - 126.03s)
# sleeping for 0.23 seconds (128.00s - 127.77s)
# sleeping for 1.74 seconds (129.75s - 128.01s)
# sleeping for 0.23 seconds (130.00s - 129.77s)
# sleeping for 1.72 seconds (131.75s - 130.03s)
# sleeping for 0.23 seconds (132.00s - 131.77s)
# sleeping for 1.74 seconds (133.75s - 132.01s)
# sleeping for 0.23 seconds (134.00s - 133.77s)
# sleeping for 1.73 seconds (135.75s - 134.02s)
# sleeping for 0.23 seconds (136.00s - 135.77s)
# sleeping for 1.74 seconds (137.75s - 136.01s)
# sleeping for 0.24 seconds (138.00s - 137.76s)
# sleeping for 1.74 seconds (139.75s - 138.01s)
# sleeping for 0.23 seconds (140.00s - 139.77s)
# sleeping for 1.73 seconds (141.75s - 140.02s)
# sleeping for 0.23 seconds (142.00s - 141.77s)
# sleeping for 1.72 seconds (143.75s - 142.03s)
# sleeping for 0.23 seconds (144.00s - 143.77s)
# sleeping for 1.74 seconds (145.75s - 144.01s)
# sleeping for 0.24 seconds (146.00s - 145.76s)
# sleeping for 1.74 seconds (147.75s - 146.01s)
# sleeping for -0.02 seconds (147.75s - 147.77s)
# sleeping for 0.23 seconds (148.00s - 147.77s)
# sleeping for 0.25 seconds (148.25s - 148.00s)
# sleeping for 0.24 seconds (148.50s - 148.26s)
# sleeping for 0.24 seconds (148.75s - 148.51s)
# sleeping for 0.23 seconds (149.00s - 148.77s)
# sleeping for 0.74 seconds (149.75s - 149.01s)
# sleeping for 0.24 seconds (150.00s - 149.76s)
# sleeping for 0.24 seconds (150.25s - 150.01s)
# sleeping for 0.24 seconds (150.50s - 150.26s)
# sleeping for 0.24 seconds (150.75s - 150.51s)
# sleeping for 0.23 seconds (151.00s - 150.77s)
# sleeping for 0.74 seconds (151.75s - 151.01s)
# sleeping for 0.24 seconds (152.00s - 151.76s)
# sleeping for 0.24 seconds (152.25s - 152.01s)
# sleeping for 0.24 seconds (152.50s - 152.26s)
# sleeping for 0.24 seconds (152.75s - 152.51s)
# sleeping for 0.24 seconds (153.00s - 152.76s)
# sleeping for 0.74 seconds (153.75s - 153.01s)
# sleeping for 0.23 seconds (154.00s - 153.77s)
# sleeping for 0.23 seconds (154.25s - 154.02s)
# sleeping for 0.23 seconds (154.50s - 154.27s)
# sleeping for 0.24 seconds (154.75s - 154.51s)
# sleeping for 0.24 seconds (155.00s - 154.76s)
# sleeping for 0.74 seconds (155.75s - 155.01s)
# sleeping for 0.24 seconds (156.00s - 155.76s)
# sleeping for 0.24 seconds (156.25s - 156.01s)
# sleeping for 0.23 seconds (156.50s - 156.27s)
# sleeping for 0.24 seconds (156.75s - 156.51s)
# sleeping for 0.24 seconds (157.00s - 156.76s)
# sleeping for 0.74 seconds (157.75s - 157.01s)
# sleeping for 0.24 seconds (158.00s - 157.76s)
# sleeping for 0.23 seconds (158.25s - 158.02s)
# sleeping for 0.24 seconds (158.50s - 158.26s)
# sleeping for 0.24 seconds (158.75s - 158.51s)
# sleeping for 0.24 seconds (159.00s - 158.76s)
# sleeping for 0.74 seconds (159.75s - 159.01s)
# sleeping for 0.24 seconds (160.00s - 159.76s)
# sleeping for 0.23 seconds (160.25s - 160.02s)
# sleeping for 0.23 seconds (160.50s - 160.27s)
# sleeping for 0.24 seconds (160.75s - 160.51s)
# sleeping for 0.24 seconds (161.00s - 160.76s)
# sleeping for 0.74 seconds (161.75s - 161.01s)
# sleeping for 0.24 seconds (162.00s - 161.76s)
# sleeping for 0.24 seconds (162.25s - 162.01s)
# sleeping for 0.23 seconds (162.50s - 162.27s)
# sleeping for 0.24 seconds (162.75s - 162.51s)
# sleeping for 0.24 seconds (163.00s - 162.76s)
# sleeping for 0.24 seconds (163.25s - 163.01s)
# sleeping for 0.49 seconds (163.75s - 163.26s)
# sleeping for 0.24 seconds (164.00s - 163.76s)
# sleeping for 2.74 seconds (166.75s - 164.01s)

# %%
from matplotlib import pyplot as plt
import pretty_midi

pr = pretty_midi.PrettyMIDI("outputs/output.mid").get_piano_roll()

plt.imshow(pr, aspect="auto", origin="lower", cmap="Purples", interpolation="nearest")
plt.show()

# %%
file = mido.MidiFile("outputs/output.mid")
file.print_tracks()
with mido.open_output("Disklavier") as outport:
    for msg in file.play():
        if not msg.is_meta:
            outport.send(msg)
# Out:
# === Track 0
# MetaMessage('set_tempo', tempo=1000000, time=0)
# Message('note_off', channel=0, note=59, velocity=64, time=168)
# Message('note_on', channel=0, note=57, velocity=104, time=24)
# Message('note_off', channel=0, note=57, velocity=64, time=168)
# Message('note_on', channel=0, note=59, velocity=104, time=24)
# Message('note_off', channel=0, note=59, velocity=64, time=168)
# Message('note_on', channel=0, note=57, velocity=104, time=24)
# Message('note_off', channel=0, note=57, velocity=64, time=168)
# Message('note_on', channel=0, note=59, velocity=104, time=96)
# Message('note_off', channel=0, note=59, velocity=64, time=168)
# Message('note_on', channel=0, note=59, velocity=104, time=24)
# Message('note_off', channel=0, note=59, velocity=64, time=168)
# Message('note_on', channel=0, note=59, velocity=104, time=24)
# Message('note_off', channel=0, note=59, velocity=64, time=168)
# Message('note_on', channel=0, note=59, velocity=104, time=24)
# Message('note_off', channel=0, note=59, velocity=64, time=168)
# Message('note_on', channel=0, note=72, velocity=100, time=96)
# Message('note_off', channel=0, note=72, velocity=64, time=648)
# Message('note_on', channel=0, note=72, velocity=97, time=96)
# Message('note_off', channel=0, note=72, velocity=64, time=648)
# Message('note_on', channel=0, note=60, velocity=104, time=96)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=58, velocity=104, time=24)
# Message('note_off', channel=0, note=58, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=58, velocity=104, time=24)
# Message('note_off', channel=0, note=58, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=96)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=58, velocity=104, time=24)
# Message('note_off', channel=0, note=58, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=62, velocity=104, time=24)
# Message('note_off', channel=0, note=62, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=96)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=58, velocity=104, time=24)
# Message('note_off', channel=0, note=58, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=62, velocity=104, time=24)
# Message('note_off', channel=0, note=62, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=96)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=168)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=72)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=24)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_on', channel=0, note=58, velocity=104, time=24)
# Message('note_on', channel=0, note=60, velocity=104, time=48)
# Message('note_off', channel=0, note=60, velocity=64, time=24)
# Message('note_off', channel=0, note=58, velocity=64, time=264)
# MetaMessage('end_of_track', time=0)
