# %%
import os
import mido

# %%
ticks_per_beat_counts = {}
for midi_file in os.listdir("../data/datasets/test/play"):
    file_path = f"../data/datasets/test/play/{midi_file}"
    midi_in = mido.MidiFile(file_path)

    tpb = midi_in.ticks_per_beat

    if tpb in ticks_per_beat_counts:
        ticks_per_beat_counts[tpb] += 1
    else:
        ticks_per_beat_counts[tpb] = 1

print("Ticks per beat counts:")
for tpb, count in ticks_per_beat_counts.items():
    print(f"{tpb}: {count} file(s)")
# Out:
# Ticks per beat counts:
# 220: 120 file(s)
# 96: 13 file(s)

# %%
file_path = "../data/outputs/logs/240909-162611/playlist/00 cccc-060-01_0000-0005.mid"
midi_in = mido.MidiFile(file_path)

print(midi_in.ticks_per_beat)

for track in midi_in.tracks:
    print(track.name)
    for msg in track:
        print(msg)
# Out:
# 96
# cccc-060-01_0000-0005
# MetaMessage('track_name', name='cccc-060-01_0000-0005', time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=36, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=36, notated_32nd_notes_per_beat=8, time=0)
# note_on channel=0 note=60 velocity=104 time=96
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# MetaMessage('end_of_track', time=0)

# %%
file_path = "../data/outputs/logs/240909-163258/recording_240909-163258.mid"
midi_in = mido.MidiFile(file_path)

print(midi_in.ticks_per_beat)

for track in midi_in.tracks:
    print(track.name)
    for msg in track:
        print(msg)
# Out:
# 480
# recording_240909-163258.mid
# MetaMessage('track_name', name='recording_240909-163258.mid', time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=36, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('set_tempo', tempo=750000, time=0)
# MetaMessage('text', text='transition 0 (6.00s)', time=768)
# MetaMessage('text', text='tick 0-1 (6.00s)', time=96)
# MetaMessage('text', text='tick 0-2 (6.75s)', time=96)
# MetaMessage('text', text='tick 0-3 (7.50s)', time=96)
# MetaMessage('text', text='tick 0-4 (8.25s)', time=96)
# MetaMessage('text', text='tick 0-5 (9.00s)', time=96)
# MetaMessage('text', text='tick 0-6 (9.75s)', time=96)
# MetaMessage('text', text='tick 0-7 (10.50s)', time=96)
# MetaMessage('text', text='tick 0-8 (11.25s)', time=96)
# MetaMessage('text', text='transition 1 (12.00s)', time=1536)
# MetaMessage('text', text='tick 1-1 (12.00s)', time=96)
# MetaMessage('text', text='tick 1-2 (12.75s)', time=96)
# MetaMessage('text', text='tick 1-3 (13.50s)', time=96)
# MetaMessage('text', text='tick 1-4 (14.25s)', time=96)
# MetaMessage('text', text='tick 1-5 (15.00s)', time=96)
# MetaMessage('text', text='tick 1-6 (15.75s)', time=96)
# MetaMessage('text', text='tick 1-7 (16.50s)', time=96)
# MetaMessage('text', text='tick 1-8 (17.25s)', time=96)
# MetaMessage('text', text='transition 2 (18.00s)', time=2304)
# MetaMessage('text', text='tick 2-1 (18.00s)', time=96)
# MetaMessage('text', text='tick 2-2 (18.75s)', time=96)
# MetaMessage('text', text='tick 2-3 (19.50s)', time=96)
# MetaMessage('text', text='tick 2-4 (20.25s)', time=96)
# MetaMessage('text', text='tick 2-5 (21.00s)', time=96)
# MetaMessage('text', text='tick 2-6 (21.75s)', time=96)
# MetaMessage('text', text='tick 2-7 (22.50s)', time=96)
# MetaMessage('text', text='tick 2-8 (23.25s)', time=96)
# MetaMessage('text', text='transition 3 (24.00s)', time=3072)
# MetaMessage('text', text='tick 3-1 (24.00s)', time=96)
# MetaMessage('text', text='tick 3-2 (24.75s)', time=96)
# MetaMessage('text', text='tick 3-3 (25.50s)', time=96)
# MetaMessage('text', text='tick 3-4 (26.25s)', time=96)
# MetaMessage('text', text='tick 3-5 (27.00s)', time=96)
# MetaMessage('text', text='tick 3-6 (27.75s)', time=96)
# MetaMessage('text', text='tick 3-7 (28.50s)', time=96)
# MetaMessage('text', text='tick 3-8 (29.25s)', time=96)
# MetaMessage('text', text='transition 4 (30.00s)', time=3840)
# MetaMessage('text', text='tick 4-1 (30.00s)', time=96)
# MetaMessage('text', text='tick 4-2 (30.75s)', time=96)
# MetaMessage('text', text='tick 4-3 (31.50s)', time=96)
# MetaMessage('text', text='tick 4-4 (32.25s)', time=96)
# MetaMessage('text', text='tick 4-5 (33.00s)', time=96)
# MetaMessage('text', text='tick 4-6 (33.75s)', time=96)
# MetaMessage('text', text='tick 4-7 (34.50s)', time=96)
# MetaMessage('text', text='tick 4-8 (35.25s)', time=96)
# MetaMessage('text', text='transition 5 (36.00s)', time=4608)
# MetaMessage('text', text='tick 5-1 (36.00s)', time=96)
# MetaMessage('text', text='tick 5-2 (36.75s)', time=96)
# MetaMessage('text', text='tick 5-3 (37.50s)', time=96)
# MetaMessage('text', text='tick 5-4 (38.25s)', time=96)
# MetaMessage('text', text='tick 5-5 (39.00s)', time=96)
# MetaMessage('text', text='tick 5-6 (39.75s)', time=96)
# MetaMessage('text', text='tick 5-7 (40.50s)', time=96)
# MetaMessage('text', text='tick 5-8 (41.25s)', time=96)
# MetaMessage('text', text='transition 6 (42.00s)', time=5376)
# MetaMessage('text', text='tick 6-1 (42.00s)', time=96)
# MetaMessage('text', text='tick 6-2 (42.75s)', time=96)
# MetaMessage('text', text='tick 6-3 (43.50s)', time=96)
# MetaMessage('text', text='tick 6-4 (44.25s)', time=96)
# MetaMessage('text', text='tick 6-5 (45.00s)', time=96)
# MetaMessage('text', text='tick 6-6 (45.75s)', time=96)
# MetaMessage('text', text='tick 6-7 (46.50s)', time=96)
# MetaMessage('text', text='tick 6-8 (47.25s)', time=96)
# MetaMessage('text', text='transition 7 (48.00s)', time=6144)
# MetaMessage('text', text='tick 7-1 (48.00s)', time=96)
# MetaMessage('text', text='tick 7-2 (48.75s)', time=96)
# MetaMessage('text', text='tick 7-3 (49.50s)', time=96)
# MetaMessage('text', text='tick 7-4 (50.25s)', time=96)
# MetaMessage('text', text='tick 7-5 (51.00s)', time=96)
# MetaMessage('text', text='tick 7-6 (51.75s)', time=96)
# MetaMessage('text', text='tick 7-7 (52.50s)', time=96)
# MetaMessage('text', text='tick 7-8 (53.25s)', time=96)
# MetaMessage('text', text='transition 8 (54.00s)', time=6912)
# MetaMessage('text', text='tick 8-1 (54.00s)', time=96)
# MetaMessage('text', text='tick 8-2 (54.75s)', time=96)
# MetaMessage('text', text='tick 8-3 (55.50s)', time=96)
# MetaMessage('text', text='tick 8-4 (56.25s)', time=96)
# MetaMessage('text', text='tick 8-5 (57.00s)', time=96)
# MetaMessage('text', text='tick 8-6 (57.75s)', time=96)
# MetaMessage('text', text='tick 8-7 (58.50s)', time=96)
# MetaMessage('text', text='tick 8-8 (59.25s)', time=96)
# MetaMessage('text', text='transition 9 (60.00s)', time=7680)
# MetaMessage('text', text='tick 9-1 (60.00s)', time=96)
# MetaMessage('text', text='tick 9-2 (60.75s)', time=96)
# MetaMessage('text', text='tick 9-3 (61.50s)', time=96)
# MetaMessage('text', text='tick 9-4 (62.25s)', time=96)
# MetaMessage('text', text='tick 9-5 (63.00s)', time=96)
# MetaMessage('text', text='tick 9-6 (63.75s)', time=96)
# MetaMessage('text', text='tick 9-7 (64.50s)', time=96)
# MetaMessage('text', text='tick 9-8 (65.25s)', time=96)
# MetaMessage('end_of_track', time=1)
# playback
# MetaMessage('track_name', name='playback', time=0)
# note_on channel=0 note=60 velocity=104 time=96
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=96
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=96
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=96
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=96
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# note_on channel=0 note=60 velocity=104 time=24
# note_off channel=0 note=60 velocity=64 time=168
# MetaMessage('end_of_track', time=0)
