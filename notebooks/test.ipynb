# %%
import mido

midi = mido.MidiFile("tmp/MIDI.mid")
midi.print_tracks()
midi.length
# Out:
# === Track 0
# MetaMessage('track_name', name='MIDI', time=0)
# MetaMessage('time_signature', numerator=1, denominator=4, clocks_per_click=36, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('time_signature', numerator=1, denominator=4, clocks_per_click=36, notated_32nd_notes_per_beat=8, time=0)
# Message('note_on', channel=0, note=31, velocity=40, time=3934)
# Message('note_on', channel=0, note=53, velocity=44, time=106)
# Message('note_on', channel=0, note=62, velocity=49, time=0)
# Message('note_off', channel=0, note=31, velocity=55, time=1)
# Message('note_on', channel=0, note=58, velocity=37, time=2)
# Message('note_off', channel=0, note=53, velocity=45, time=31)
# Message('note_off', channel=0, note=58, velocity=54, time=3)
# Message('note_off', channel=0, note=62, velocity=35, time=4)
# Message('note_on', channel=0, note=31, velocity=38, time=4)
# Message('note_on', channel=0, note=36, velocity=29, time=49)
# Message('note_on', channel=0, note=60, velocity=34, time=3)
# ...

# %%
x = range(5)

for y in x:
    print(y)
    if y > 2:
        break
# Out:
# 0
# 1
# 2
# 3

# %%
1 - 0.9465333333333333
# Out:
# 0.05346666666666666

# %%
sum(
    [
        1 / 5,  # same
        1 / 6,  # next 1
        1 / 6,  # prev 1
        1 / 10,  # next 2
        1 / 10,  # prev 2
        0.0533,  # diff 1
        0.0533,  # diff 2
        0.0533,  # diff 3
        0.0533,  # diff 4
        0.0534,  # diff 5
    ]
)
# Out:
# 0.9999333333333333

# %%
name = "20240213-100-05_0259-0268_d02.mid"
name.rsplit("_")
# Out:
# ['20240213-100-05', '0259-0268', 'd02.mid']
