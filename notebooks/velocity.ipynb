# %%
import os
import mido
import pretty_midi
import random
import numpy as np
import time

# %%
raw_dir = os.path.join("..", "inputs", "all-fourbar")
files = os.listdir(raw_dir)
random.shuffle(files)

# %%
def fade(current_value, current_time, end_time):
    """
    Scales the current value to zero by the end time.

    Parameters:
    - current_value: The current value to scale.
    - current_time: The current time in ticks
    - end_time: The end time by which the value should reach 0.

    Returns:
    - The scaled value, which linearly decreases to 0 by the end time. If the current time is past the end time, it returns 0.
    """

    scaling_factor = 1 - current_time / (end_time * 8.0)
    scaled_value = current_value * scaling_factor

    return scaled_value

# %%
volume = 1.0
runtime = 0.0
with mido.open_output("Disklavier") as output:
    midi = mido.MidiFile(os.path.join(raw_dir, files[0]))
    for msg in midi.play():
        runtime += msg.time
        volume = fade(volume, runtime, midi.length)
        scaled_msg = msg
        if hasattr(msg, "velocity"):
            scaled_msg.velocity = round(scaled_msg.velocity * volume)
            print(f"scaling vel by {volume:.03f} of msg {scaled_msg}")
        output.send(scaled_msg)
# Out:
# 0.0 / 14.771504727272726 -> 1.0
# 0.12167833181818181 / 14.771504727272726 -> 0.9989703289029729
# scaling vel by 0.999 of msg note_on channel=0 note=69 velocity=74 time=0.12167833181818181
# 0.1300699409090909 / 14.771504727272726 -> 0.9988993171031779
# scaling vel by 0.998 of msg note_on channel=0 note=67 velocity=70 time=0.00839160909090909
# 0.16783218181818182 / 14.771504727272726 -> 0.9985797640041004
# scaling vel by 0.996 of msg note_on channel=0 note=67 velocity=0 time=0.03776224090909091
# 0.49510493636363634 / 14.771504727272726 -> 0.9958103038120965
# scaling vel by 0.992 of msg note_on channel=0 note=57 velocity=56 time=0.3272727545454545
# 0.49510493636363634 / 14.771504727272726 -> 0.9958103038120965
# scaling vel by 0.988 of msg note_on channel=0 note=60 velocity=54 time=0
# 0.5160839590909091 / 14.771504727272726 -> 0.995632774312609
# scaling vel by 0.984 of msg note_on channel=0 note=64 velocity=65 time=0.020979022727272728
# 0.5832168318181818 / 14.771504727272726 -> 0.9950646799142492
# scaling vel by 0.979 of msg note_on channel=0 note=57 velocity=0 time=0.06713287272727272
# 0.6209790727272727 / 14.771504727272726 -> 0.9947451268151718
# scaling vel by 0.974 of msg note_on channel=0 note=45 velocity=60 time=0.03776224090909091
# 0.6293706818181818 / 14.771504727272726 -> 0.9946741150153767
# scaling vel by 0.969 of msg note_on channel=0 note=60 velocity=0 time=0.00839160909090909
# 0.6419580954545454 / 14.771504727272726 -> 0.9945675973156843
# scaling vel by 0.963 of msg note_on channel=0 note=64 velocity=0 time=0.012587413636363636
# 0.6881119454545455 / 14.771504727272726 -> 0.994177032416812
# scaling vel by 0.958 of msg note_on channel=0 note=45 velocity=0 time=0.046153849999999996
# 0.9398602181818182 / 14.771504727272726 -> 0.9920466784229627
# scaling vel by 0.950 of msg note_on channel=0 note=45 velocity=61 time=0.25174827272727274
# 1.2167833181818182 / 14.771504727272726 -> 0.9897032890297285
# scaling vel by 0.940 of msg note_on channel=0 note=57 velocity=60 time=0.2769231
# 1.2251749272727273 / 14.771504727272726 -> 0.9896322772299334
# scaling vel by 0.931 of msg note_on channel=0 note=60 velocity=60 time=0.00839160909090909
# 1.2251749272727273 / 14.771504727272726 -> 0.9896322772299334
# scaling vel by 0.921 of msg note_on channel=0 note=64 velocity=57 time=0
# 1.3048952136363636 / 14.771504727272726 -> 0.9889576651318812
# scaling vel by 0.911 of msg note_on channel=0 note=45 velocity=0 time=0.07972028636363636
# 1.3342658454545455 / 14.771504727272726 -> 0.9887091238325988
# scaling vel by 0.900 of msg note_on channel=0 note=57 velocity=0 time=0.029370631818181815
# 1.3720280863636365 / 14.771504727272726 -> 0.9883895707335214
# scaling vel by 0.890 of msg note_on channel=0 note=60 velocity=0 time=0.03776224090909091
# 1.3804196954545456 / 14.771504727272726 -> 0.9883185589337264
# scaling vel by 0.880 of msg note_on channel=0 note=64 velocity=0 time=0.00839160909090909
# 1.468531590909091 / 14.771504727272726 -> 0.9875729350358792
# scaling vel by 0.869 of msg note_on channel=0 note=45 velocity=57 time=0.08811189545454545
# 1.699300840909091 / 14.771504727272726 -> 0.9856201105415173
# scaling vel by 0.856 of msg note_on channel=0 note=69 velocity=0 time=0.23076924999999998
# 1.7538463000000002 / 14.771504727272726 -> 0.9851585338428499
# scaling vel by 0.844 of msg note_on channel=0 note=45 velocity=0 time=0.05454545909090909
# 1.8125875636363638 / 14.771504727272726 -> 0.9846614512442852
# scaling vel by 0.831 of msg note_on channel=0 note=40 velocity=57 time=0.05874126363636363
# 2.1020980772727276 / 14.771504727272726 -> 0.9822115441513585
# scaling vel by 0.816 of msg note_on channel=0 note=62 velocity=66 time=0.2895105136363636
# 2.110489686363637 / 14.771504727272726 -> 0.9821405323515635
# scaling vel by 0.801 of msg note_on channel=0 note=56 velocity=58 time=0.00839160909090909
# 2.110489686363637 / 14.771504727272726 -> 0.9821405323515635
# scaling vel by 0.787 of msg note_on channel=0 note=59 velocity=58 time=0
# 2.2825176727272734 / 14.771504727272726 -> 0.9806847904557664
# scaling vel by 0.772 of msg note_on channel=0 note=56 velocity=0 time=0.17202798636363636
# 2.4000002000000005 / 14.771504727272726 -> 0.9796906252586368
# scaling vel by 0.756 of msg note_on channel=0 note=47 velocity=45 time=0.11748252727272726
# 2.4000002000000005 / 14.771504727272726 -> 0.9796906252586368
# scaling vel by 0.741 of msg note_on channel=0 note=59 velocity=0 time=0
# 2.4083918090909098 / 14.771504727272726 -> 0.9796196134588419
# scaling vel by 0.726 of msg note_on channel=0 note=62 velocity=0 time=0.00839160909090909
# 2.718881345454546 / 14.771504727272726 -> 0.9769921768664277
# scaling vel by 0.709 of msg note_on channel=0 note=62 velocity=54 time=0.31048953636363635
# 2.7272729545454553 / 14.771504727272726 -> 0.9769211650666327
# scaling vel by 0.693 of msg note_on channel=0 note=56 velocity=45 time=0.00839160909090909
# 2.7272729545454553 / 14.771504727272726 -> 0.9769211650666327
# scaling vel by 0.677 of msg note_on channel=0 note=59 velocity=43 time=0
# 2.9202799636363643 / 14.771504727272726 -> 0.9752878936713483
# scaling vel by 0.660 of msg note_on channel=0 note=56 velocity=0 time=0.1930070090909091
# 2.987412836363637 / 14.771504727272726 -> 0.9747197992729885
# scaling vel by 0.643 of msg note_on channel=0 note=65 velocity=55 time=0.06713287272727272
# 3.004196054545455 / 14.771504727272726 -> 0.9745777756733985
# scaling vel by 0.627 of msg note_on channel=0 note=56 velocity=43 time=0.01678321818181818
# 3.1216785818181823 / 14.771504727272726 -> 0.9735836104762688
# scaling vel by 0.610 of msg note_on channel=0 note=47 velocity=0 time=0.11748252727272726
# 3.159440822727273 / 14.771504727272726 -> 0.9732640573771915
# scaling vel by 0.594 of msg note_on channel=0 note=65 velocity=0 time=0.03776224090909091
# 3.264335936363637 / 14.771504727272726 -> 0.9723764098797543
# scaling vel by 0.578 of msg note_on channel=0 note=47 velocity=24 time=0.10489511363636363
# 3.3146855909090913 / 14.771504727272726 -> 0.9719503390809844
# scaling vel by 0.561 of msg note_on channel=0 note=62 velocity=0 time=0.05034965454545454
# 3.3146855909090913 / 14.771504727272726 -> 0.9719503390809844
# scaling vel by 0.546 of msg note_on channel=0 note=64 velocity=34 time=0
# 3.3230772000000006 / 14.771504727272726 -> 0.9718793272811894
# scaling vel by 0.530 of msg note_on channel=0 note=56 velocity=0 time=0.00839160909090909
# 3.3230772000000006 / 14.771504727272726 -> 0.9718793272811894
# scaling vel by 0.515 of msg note_on channel=0 note=59 velocity=0 time=0
# 3.465734554545455 / 14.771504727272726 -> 0.9706721266846748
# scaling vel by 0.500 of msg note_on channel=0 note=64 velocity=0 time=0.14265735454545453
# 3.5622380590909097 / 14.771504727272726 -> 0.9698554909870326
# scaling vel by 0.485 of msg note_on channel=0 note=40 velocity=0 time=0.09650350454545455
# 3.5916086909090916 / 14.771504727272726 -> 0.9696069496877502
# scaling vel by 0.470 of msg note_on channel=0 note=47 velocity=0 time=0.029370631818181815
# 3.641958345454546 / 14.771504727272726 -> 0.9691808788889803
# scaling vel by 0.456 of msg note_on channel=0 note=33 velocity=31 time=0.05034965454545454
# 3.8139863318181826 / 14.771504727272726 -> 0.9677251369931833
# scaling vel by 0.441 of msg note_on channel=0 note=64 velocity=36 time=0.17202798636363636
# 3.822377940909092 / 14.771504727272726 -> 0.9676541251933883
# scaling vel by 0.427 of msg note_on channel=0 note=54 velocity=30 time=0.00839160909090909
# 3.822377940909092 / 14.771504727272726 -> 0.9676541251933883
# scaling vel by 0.413 of msg note_on channel=0 note=57 velocity=29 time=0
# 3.822377940909092 / 14.771504727272726 -> 0.9676541251933883
# scaling vel by 0.400 of msg note_on channel=0 note=60 velocity=28 time=0
# 4.053147190909092 / 14.771504727272726 -> 0.9657013006990265
# scaling vel by 0.386 of msg note_on channel=0 note=54 velocity=0 time=0.23076924999999998
# 4.053147190909092 / 14.771504727272726 -> 0.9657013006990265
# scaling vel by 0.373 of msg note_on channel=0 note=57 velocity=0 time=0
# 4.053147190909092 / 14.771504727272726 -> 0.9657013006990265
# scaling vel by 0.360 of msg note_on channel=0 note=60 velocity=0 time=0
# 4.090909431818183 / 14.771504727272726 -> 0.9653817475999491
# scaling vel by 0.348 of msg note_on channel=0 note=64 velocity=0 time=0.03776224090909091
# 4.1580423045454555 / 14.771504727272726 -> 0.9648136532015893
# scaling vel by 0.335 of msg note_on channel=0 note=45 velocity=13 time=0.06713287272727272
# 4.246154200000001 / 14.771504727272726 -> 0.964068029303742
# scaling vel by 0.323 of msg note_on channel=0 note=64 velocity=24 time=0.08811189545454545
# 4.25454580909091 / 14.771504727272726 -> 0.9639970175039471
# scaling vel by 0.312 of msg note_on channel=0 note=45 velocity=0 time=0.00839160909090909
# 4.25454580909091 / 14.771504727272726 -> 0.9639970175039471
# scaling vel by 0.300 of msg note_on channel=0 note=57 velocity=18 time=0
# 4.25454580909091 / 14.771504727272726 -> 0.9639970175039471
# scaling vel by 0.290 of msg note_on channel=0 note=60 velocity=15 time=0
# 4.267133222727273 / 14.771504727272726 -> 0.9638904998042546
# scaling vel by 0.279 of msg note_on channel=0 note=54 velocity=16 time=0.012587413636363636
# 4.418182186363637 / 14.771504727272726 -> 0.962612287407945
# scaling vel by 0.269 of msg note_on channel=0 note=54 velocity=0 time=0.15104896363636364
# 4.418182186363637 / 14.771504727272726 -> 0.962612287407945
# scaling vel by 0.259 of msg note_on channel=0 note=60 velocity=0 time=0
# 4.418182186363637 / 14.771504727272726 -> 0.962612287407945
# scaling vel by 0.249 of msg note_on channel=0 note=64 velocity=0 time=0
# 4.426573795454546 / 14.771504727272726 -> 0.9625412756081501
# scaling vel by 0.240 of msg note_on channel=0 note=57 velocity=0 time=0.00839160909090909
# 4.5524479318181825 / 14.771504727272726 -> 0.9614760986112254
# scaling vel by 0.230 of msg note_on channel=0 note=45 velocity=13 time=0.12587413636363637
# 4.657343045454546 / 14.771504727272726 -> 0.9605884511137882
# scaling vel by 0.221 of msg note_on channel=0 note=33 velocity=0 time=0.10489511363636363
# 4.850350054545455 / 14.771504727272726 -> 0.9589551797185037
# scaling vel by 0.212 of msg note_on channel=0 note=54 velocity=14 time=0.1930070090909091
# 4.850350054545455 / 14.771504727272726 -> 0.9589551797185037
# scaling vel by 0.204 of msg note_on channel=0 note=57 velocity=15 time=0
# 4.850350054545455 / 14.771504727272726 -> 0.9589551797185037
# scaling vel by 0.195 of msg note_on channel=0 note=64 velocity=13 time=0
# 4.862937468181818 / 14.771504727272726 -> 0.9588486620188112
# scaling vel by 0.187 of msg note_on channel=0 note=60 velocity=12 time=0.012587413636363636
# 5.177622809090909 / 14.771504727272726 -> 0.9561857195264997
# scaling vel by 0.179 of msg note_on channel=0 note=35 velocity=12 time=0.3146853409090909
# 5.227972463636364 / 14.771504727272726 -> 0.9557596487277298
# scaling vel by 0.171 of msg note_on channel=0 note=45 velocity=0 time=0.05034965454545454
# 5.282517922727274 / 14.771504727272726 -> 0.9552980720290625
# scaling vel by 0.163 of msg note_on channel=0 note=54 velocity=0 time=0.05454545909090909
# 5.282517922727274 / 14.771504727272726 -> 0.9552980720290625
# scaling vel by 0.156 of msg note_on channel=0 note=57 velocity=0 time=0
# 5.3328675772727285 / 14.771504727272726 -> 0.9548720012302926
# scaling vel by 0.149 of msg note_on channel=0 note=64 velocity=0 time=0.05034965454545454
# 5.341259186363637 / 14.771504727272726 -> 0.9548009894304976
# scaling vel by 0.142 of msg note_on channel=0 note=60 velocity=0 time=0.00839160909090909
# 5.420979472727273 / 14.771504727272726 -> 0.9541263773324453
# scaling vel by 0.136 of msg note_on channel=0 note=35 velocity=0 time=0.07972028636363636
# 5.467133322727273 / 14.771504727272726 -> 0.953735812433573
# scaling vel by 0.129 of msg note_on channel=0 note=40 velocity=9 time=0.046153849999999996
# 5.676923550000001 / 14.771504727272726 -> 0.9519605174386986
# scaling vel by 0.123 of msg note_on channel=0 note=56 velocity=9 time=0.20979022727272725
# 5.676923550000001 / 14.771504727272726 -> 0.9519605174386986
# scaling vel by 0.117 of msg note_on channel=0 note=59 velocity=8 time=0
# 5.676923550000001 / 14.771504727272726 -> 0.9519605174386986
# scaling vel by 0.112 of msg note_on channel=0 note=62 velocity=9 time=0
# 5.861538950000001 / 14.771504727272726 -> 0.9503982578432091
# scaling vel by 0.106 of msg note_on channel=0 note=40 velocity=0 time=0.18461539999999999
# 5.882517972727274 / 14.771504727272726 -> 0.9502207283437216
# scaling vel by 0.101 of msg note_on channel=0 note=56 velocity=0 time=0.020979022727272728
# 5.899301190909092 / 14.771504727272726 -> 0.9500787047441317
# scaling vel by 0.096 of msg note_on channel=0 note=59 velocity=0 time=0.01678321818181818
# 5.928671822727274 / 14.771504727272726 -> 0.9498301634448493
# scaling vel by 0.091 of msg note_on channel=0 note=62 velocity=0 time=0.029370631818181815
# 5.966434063636365 / 14.771504727272726 -> 0.9495106103457719
# scaling vel by 0.086 of msg note_on channel=0 note=40 velocity=4 time=0.03776224090909091
# 6.10069980909091 / 14.771504727272726 -> 0.9483744215490523
# scaling vel by 0.082 of msg note_on channel=0 note=59 velocity=5 time=0.13426574545454545
# 6.10069980909091 / 14.771504727272726 -> 0.9483744215490523
# scaling vel by 0.078 of msg note_on channel=0 note=62 velocity=6 time=0
# 6.113287222727274 / 14.771504727272726 -> 0.9482679038493598
# scaling vel by 0.074 of msg note_on channel=0 note=56 velocity=5 time=0.012587413636363636
# 6.323077450000001 / 14.771504727272726 -> 0.9464926088544854
# scaling vel by 0.070 of msg note_on channel=0 note=62 velocity=0 time=0.20979022727272725
# 6.33146905909091 / 14.771504727272726 -> 0.9464215970546904
# scaling vel by 0.066 of msg note_on channel=0 note=56 velocity=0 time=0.00839160909090909
# 6.3440564727272735 / 14.771504727272726 -> 0.9463150793549979
# scaling vel by 0.063 of msg note_on channel=0 note=59 velocity=0 time=0.012587413636363636
# 6.448951586363637 / 14.771504727272726 -> 0.9454274318575607
# scaling vel by 0.059 of msg note_on channel=0 note=47 velocity=3 time=0.10489511363636363
# 6.734266295454546 / 14.771504727272726 -> 0.9430130306645316
# scaling vel by 0.056 of msg note_on channel=0 note=59 velocity=3 time=0.28531470909090906
# 6.734266295454546 / 14.771504727272726 -> 0.9430130306645316
# scaling vel by 0.053 of msg note_on channel=0 note=65 velocity=4 time=0
# 6.746853709090909 / 14.771504727272726 -> 0.9429065129648391
# scaling vel by 0.050 of msg note_on channel=0 note=56 velocity=3 time=0.012587413636363636
# 6.746853709090909 / 14.771504727272726 -> 0.9429065129648391
# scaling vel by 0.047 of msg note_on channel=0 note=62 velocity=3 time=0
# 6.881119454545455 / 14.771504727272726 -> 0.9417703241681195
# scaling vel by 0.044 of msg note_on channel=0 note=56 velocity=0 time=0.13426574545454545
# 6.948252327272727 / 14.771504727272726 -> 0.9412022297697596
# scaling vel by 0.041 of msg note_on channel=0 note=65 velocity=0 time=0.06713287272727272
# 7.023776809090909 / 14.771504727272726 -> 0.9405631235716049
# scaling vel by 0.039 of msg note_on channel=0 note=56 velocity=3 time=0.07552448181818182
# 7.023776809090909 / 14.771504727272726 -> 0.9405631235716049
# scaling vel by 0.037 of msg note_on channel=0 note=64 velocity=3 time=0
# 7.074126463636364 / 14.771504727272726 -> 0.940137052772835
# scaling vel by 0.034 of msg note_on channel=0 note=40 velocity=0 time=0.05034965454545454
# 7.179021577272727 / 14.771504727272726 -> 0.9392494052753978
# scaling vel by 0.032 of msg note_on channel=0 note=47 velocity=0 time=0.10489511363636363
# 7.179021577272727 / 14.771504727272726 -> 0.9392494052753978
# scaling vel by 0.030 of msg note_on channel=0 note=62 velocity=0 time=0
# 7.187413186363636 / 14.771504727272726 -> 0.9391783934756028
# scaling vel by 0.029 of msg note_on channel=0 note=59 velocity=0 time=0.00839160909090909
# 7.208392209090909 / 14.771504727272726 -> 0.9390008639761154
# scaling vel by 0.027 of msg note_on channel=0 note=64 velocity=0 time=0.020979022727272728
# 7.237762840909091 / 14.771504727272726 -> 0.938752322676833
# scaling vel by 0.025 of msg note_on channel=0 note=56 velocity=0 time=0.029370631818181815
# 7.342657954545454 / 14.771504727272726 -> 0.9378646751793958
# scaling vel by 0.024 of msg note_on channel=0 note=33 velocity=2 time=0.10489511363636363
# 7.506294331818181 / 14.771504727272726 -> 0.9364799450833937
# scaling vel by 0.022 of msg note_on channel=0 note=64 velocity=2 time=0.16363637727272726
# 7.51468594090909 / 14.771504727272726 -> 0.9364089332835988
# scaling vel by 0.021 of msg note_on channel=0 note=54 velocity=2 time=0.00839160909090909
# 7.51468594090909 / 14.771504727272726 -> 0.9364089332835988
# scaling vel by 0.019 of msg note_on channel=0 note=57 velocity=1 time=0
# 7.51468594090909 / 14.771504727272726 -> 0.9364089332835988
# scaling vel by 0.018 of msg note_on channel=0 note=60 velocity=1 time=0
# 7.640560077272727 / 14.771504727272726 -> 0.9353437562866741
# scaling vel by 0.017 of msg note_on channel=0 note=54 velocity=0 time=0.12587413636363637
# 7.640560077272727 / 14.771504727272726 -> 0.9353437562866741
# scaling vel by 0.016 of msg note_on channel=0 note=64 velocity=0 time=0
# 7.669930709090909 / 14.771504727272726 -> 0.9350952149873917
# scaling vel by 0.015 of msg note_on channel=0 note=57 velocity=0 time=0.029370631818181815
# 7.678322318181817 / 14.771504727272726 -> 0.9350242031875967
# scaling vel by 0.014 of msg note_on channel=0 note=60 velocity=0 time=0.00839160909090909
# 7.812588063636363 / 14.771504727272726 -> 0.9338880143908771
# scaling vel by 0.013 of msg note_on channel=0 note=45 velocity=1 time=0.13426574545454545
# 7.938462199999999 / 14.771504727272726 -> 0.9328228373939524
# scaling vel by 0.012 of msg note_on channel=0 note=54 velocity=1 time=0.12587413636363637
# 7.938462199999999 / 14.771504727272726 -> 0.9328228373939524
# scaling vel by 0.011 of msg note_on channel=0 note=64 velocity=1 time=0
# 7.946853809090908 / 14.771504727272726 -> 0.9327518255941575
# scaling vel by 0.011 of msg note_on channel=0 note=57 velocity=1 time=0.00839160909090909
# 7.946853809090908 / 14.771504727272726 -> 0.9327518255941575
# scaling vel by 0.010 of msg note_on channel=0 note=60 velocity=1 time=0
# 8.026574095454544 / 14.771504727272726 -> 0.9320772134961052
# scaling vel by 0.009 of msg note_on channel=0 note=33 velocity=0 time=0.07972028636363636
# 8.23636432272727 / 14.771504727272726 -> 0.9303019185012308
# scaling vel by 0.009 of msg note_on channel=0 note=33 velocity=1 time=0.20979022727272725
# 8.24475593181818 / 14.771504727272726 -> 0.9302309067014358
# scaling vel by 0.008 of msg note_on channel=0 note=45 velocity=0 time=0.00839160909090909
# 8.28251817272727 / 14.771504727272726 -> 0.9299113536023584
# scaling vel by 0.007 of msg note_on channel=0 note=54 velocity=0 time=0.03776224090909091
# 8.28251817272727 / 14.771504727272726 -> 0.9299113536023584
# scaling vel by 0.007 of msg note_on channel=0 note=57 velocity=0 time=0
# 8.28251817272727 / 14.771504727272726 -> 0.9299113536023584
# scaling vel by 0.006 of msg note_on channel=0 note=64 velocity=0 time=0
# 8.303497195454543 / 14.771504727272726 -> 0.929733824102871
# scaling vel by 0.006 of msg note_on channel=0 note=60 velocity=0 time=0.020979022727272728
# 8.555245468181816 / 14.771504727272726 -> 0.9276034701090217
# scaling vel by 0.005 of msg note_on channel=0 note=54 velocity=0 time=0.25174827272727274
# 8.555245468181816 / 14.771504727272726 -> 0.9276034701090217
# scaling vel by 0.005 of msg note_on channel=0 note=57 velocity=0 time=0
# 8.555245468181816 / 14.771504727272726 -> 0.9276034701090217
# scaling vel by 0.005 of msg note_on channel=0 note=60 velocity=0 time=0
# 8.555245468181816 / 14.771504727272726 -> 0.9276034701090217
# scaling vel by 0.004 of msg note_on channel=0 note=64 velocity=0 time=0
# 8.823776959090907 / 14.771504727272726 -> 0.9253310925155824
# scaling vel by 0.004 of msg note_on channel=0 note=39 velocity=0 time=0.2685314909090909
# 8.899301440909088 / 14.771504727272726 -> 0.9246919863174277
# scaling vel by 0.004 of msg note_on channel=0 note=33 velocity=0 time=0.07552448181818182
# 9.016783968181816 / 14.771504727272726 -> 0.923697821120298
# scaling vel by 0.003 of msg note_on channel=0 note=54 velocity=0 time=0.11748252727272726
# 9.033567186363634 / 14.771504727272726 -> 0.923555797520708
# scaling vel by 0.003 of msg note_on channel=0 note=57 velocity=0 time=0.01678321818181818
# 9.062937818181815 / 14.771504727272726 -> 0.9233072562214256
# scaling vel by 0.003 of msg note_on channel=0 note=64 velocity=0 time=0.029370631818181815
# 9.083916840909088 / 14.771504727272726 -> 0.9231297267219382
# scaling vel by 0.003 of msg note_on channel=0 note=60 velocity=0 time=0.020979022727272728
# 9.11328747272727 / 14.771504727272726 -> 0.9228811854226557
# scaling vel by 0.003 of msg note_on channel=0 note=39 velocity=0 time=0.029370631818181815
# 9.15944132272727 / 14.771504727272726 -> 0.9224906205237834
# scaling vel by 0.002 of msg note_on channel=0 note=40 velocity=0 time=0.046153849999999996
# 9.302098677272724 / 14.771504727272726 -> 0.9212834199272688
# scaling vel by 0.002 of msg note_on channel=0 note=59 velocity=0 time=0.14265735454545453
# 9.302098677272724 / 14.771504727272726 -> 0.9212834199272688
# scaling vel by 0.002 of msg note_on channel=0 note=62 velocity=0 time=0
# 9.314686090909088 / 14.771504727272726 -> 0.9211769022275764
# scaling vel by 0.002 of msg note_on channel=0 note=56 velocity=0 time=0.012587413636363636
# 9.43636442272727 / 14.771504727272726 -> 0.9201472311305492
# scaling vel by 0.002 of msg note_on channel=0 note=56 velocity=0 time=0.12167833181818181
# 9.457343445454542 / 14.771504727272726 -> 0.9199697016310617
# scaling vel by 0.002 of msg note_on channel=0 note=59 velocity=0 time=0.020979022727272728
# 9.465735054545451 / 14.771504727272726 -> 0.9198986898312668
# scaling vel by 0.001 of msg note_on channel=0 note=62 velocity=0 time=0.00839160909090909
# 9.629371431818178 / 14.771504727272726 -> 0.9185139597352647
# scaling vel by 0.001 of msg note_on channel=0 note=47 velocity=0 time=0.16363637727272726
# 9.763637177272724 / 14.771504727272726 -> 0.9173777709385451
# scaling vel by 0.001 of msg note_on channel=0 note=56 velocity=0 time=0.13426574545454545
# 9.763637177272724 / 14.771504727272726 -> 0.9173777709385451
# scaling vel by 0.001 of msg note_on channel=0 note=59 velocity=0 time=0
# 9.763637177272724 / 14.771504727272726 -> 0.9173777709385451
# scaling vel by 0.001 of msg note_on channel=0 note=62 velocity=0 time=0
# 10.03636447272727 / 14.771504727272726 -> 0.9150698874452085
# scaling vel by 0.001 of msg note_on channel=0 note=56 velocity=0 time=0.27272729545454544
# 10.03636447272727 / 14.771504727272726 -> 0.9150698874452085
# scaling vel by 0.001 of msg note_on channel=0 note=59 velocity=0 time=0
# 10.044756081818178 / 14.771504727272726 -> 0.9149988756454135
# scaling vel by 0.001 of msg note_on channel=0 note=47 velocity=0 time=0.00839160909090909
# 10.053147690909087 / 14.771504727272726 -> 0.9149278638456184
# scaling vel by 0.001 of msg note_on channel=0 note=62 velocity=0 time=0.00839160909090909
# 10.090909931818178 / 14.771504727272726 -> 0.914608310746541
# scaling vel by 0.001 of msg note_on channel=0 note=52 velocity=0 time=0.03776224090909091
# 10.372028836363633 / 14.771504727272726 -> 0.9122294154534094
# scaling vel by 0.001 of msg note_on channel=0 note=59 velocity=0 time=0.2811189045454545
# 10.380420445454542 / 14.771504727272726 -> 0.9121584036536143
# scaling vel by 0.001 of msg note_on channel=0 note=56 velocity=0 time=0.00839160909090909
# 10.380420445454542 / 14.771504727272726 -> 0.9121584036536143
# scaling vel by 0.000 of msg note_on channel=0 note=62 velocity=0 time=0
# 10.380420445454542 / 14.771504727272726 -> 0.9121584036536143
# scaling vel by 0.000 of msg note_on channel=0 note=65 velocity=0 time=0
# 10.57342745454545 / 14.771504727272726 -> 0.9105251322583299
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.1930070090909091
# 10.58181906363636 / 14.771504727272726 -> 0.9104541204585349
# scaling vel by 0.000 of msg note_on channel=0 note=65 velocity=0 time=0.00839160909090909
# 10.590210672727268 / 14.771504727272726 -> 0.91038310865874
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0.00839160909090909
# 10.699301590909087 / 14.771504727272726 -> 0.9094599552614053
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0.10909091818181818
# 10.699301590909087 / 14.771504727272726 -> 0.9094599552614053
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0
# 10.707693199999996 / 14.771504727272726 -> 0.9093889434616103
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.00839160909090909
# 10.716084809090905 / 14.771504727272726 -> 0.9093179316618153
# scaling vel by 0.000 of msg note_on channel=0 note=62 velocity=0 time=0.00839160909090909
# 10.783217681818178 / 14.771504727272726 -> 0.9087498372634555
# scaling vel by 0.000 of msg note_on channel=0 note=52 velocity=0 time=0.06713287272727272
# 10.900700209090905 / 14.771504727272726 -> 0.9077556720663259
# scaling vel by 0.000 of msg note_on channel=0 note=40 velocity=0 time=0.11748252727272726
# 10.930070840909087 / 14.771504727272726 -> 0.9075071307670435
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0.029370631818181815
# 10.946854059090905 / 14.771504727272726 -> 0.9073651071674534
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.01678321818181818
# 10.946854059090905 / 14.771504727272726 -> 0.9073651071674534
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0
# 11.04335756363636 / 14.771504727272726 -> 0.9065484714698113
# scaling vel by 0.000 of msg note_on channel=0 note=33 velocity=0 time=0.09650350454545455
# 11.206993940909086 / 14.771504727272726 -> 0.9051637413738092
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0.16363637727272726
# 11.206993940909086 / 14.771504727272726 -> 0.9051637413738092
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0
# 11.206993940909086 / 14.771504727272726 -> 0.9051637413738092
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0
# 11.31188905454545 / 14.771504727272726 -> 0.9042760938763721
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0.10489511363636363
# 11.324476468181814 / 14.771504727272726 -> 0.9041695761766796
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0.012587413636363636
# 11.34965129545454 / 14.771504727272726 -> 0.9039565407772946
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0.02517482727272727
# 11.53426669545454 / 14.771504727272726 -> 0.9023942811818052
# scaling vel by 0.000 of msg note_on channel=0 note=45 velocity=0 time=0.18461539999999999
# 11.58042054545454 / 14.771504727272726 -> 0.9020037162829327
# scaling vel by 0.000 of msg note_on channel=0 note=45 velocity=0 time=0.046153849999999996
# 11.651749222727268 / 14.771504727272726 -> 0.9014001159846755
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0.07132867727272726
# 11.660140831818177 / 14.771504727272726 -> 0.9013291041848805
# scaling vel by 0.000 of msg note_on channel=0 note=54 velocity=0 time=0.00839160909090909
# 11.660140831818177 / 14.771504727272726 -> 0.9013291041848805
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0
# 11.660140831818177 / 14.771504727272726 -> 0.9013291041848805
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0
# 11.94965134545454 / 14.771504727272726 -> 0.8988791970919539
# scaling vel by 0.000 of msg note_on channel=0 note=54 velocity=0 time=0.2895105136363636
# 11.966434563636358 / 14.771504727272726 -> 0.8987371734923639
# scaling vel by 0.000 of msg note_on channel=0 note=45 velocity=0 time=0.01678321818181818
# 11.966434563636358 / 14.771504727272726 -> 0.8987371734923639
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0
# 11.974826172727267 / 14.771504727272726 -> 0.8986661616925689
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0.00839160909090909
# 11.974826172727267 / 14.771504727272726 -> 0.8986661616925689
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0
# 11.99580519545454 / 14.771504727272726 -> 0.8984886321930815
# scaling vel by 0.000 of msg note_on channel=0 note=33 velocity=0 time=0.020979022727272728
# 12.255945077272722 / 14.771504727272726 -> 0.8962872663994372
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0.2601398818181818
# 12.255945077272722 / 14.771504727272726 -> 0.8962872663994372
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0
# 12.255945077272722 / 14.771504727272726 -> 0.8962872663994372
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0
# 12.264336686363631 / 14.771504727272726 -> 0.8962162545996423
# scaling vel by 0.000 of msg note_on channel=0 note=54 velocity=0 time=0.00839160909090909
# 12.72587518636363 / 14.771504727272726 -> 0.8923106056109186
# scaling vel by 0.000 of msg note_on channel=0 note=54 velocity=0 time=0.46153849999999996
# 12.755245818181812 / 14.771504727272726 -> 0.8920620643116361
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0.029370631818181815
# 12.793008059090903 / 14.771504727272726 -> 0.8917425112125588
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0.03776224090909091
# 12.805595472727267 / 14.771504727272726 -> 0.8916359935128663
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0.012587413636363636
# 12.889511563636358 / 14.771504727272726 -> 0.8909258755149165
# scaling vel by 0.000 of msg note_on channel=0 note=40 velocity=0 time=0.08391609090909091
# 12.91049058636363 / 14.771504727272726 -> 0.8907483460154291
# scaling vel by 0.000 of msg note_on channel=0 note=45 velocity=0 time=0.020979022727272728
# 13.179022077272721 / 14.771504727272726 -> 0.8884759684219898
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.2685314909090909
# 13.179022077272721 / 14.771504727272726 -> 0.8884759684219898
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0
# 13.179022077272721 / 14.771504727272726 -> 0.8884759684219898
# scaling vel by 0.000 of msg note_on channel=0 note=62 velocity=0 time=0
# 13.60279833636363 / 14.771504727272726 -> 0.8848898725323435
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.42377625909090905
# 13.632168968181812 / 14.771504727272726 -> 0.8846413312330611
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0.029370631818181815
# 13.657343795454539 / 14.771504727272726 -> 0.8844282958336762
# scaling vel by 0.000 of msg note_on channel=0 note=62 velocity=0 time=0.02517482727272727
# 13.841959195454539 / 14.771504727272726 -> 0.8828660362381867
# scaling vel by 0.000 of msg note_on channel=0 note=52 velocity=0 time=0.18461539999999999
# 14.118882295454538 / 14.771504727272726 -> 0.8805226468449525
# scaling vel by 0.000 of msg note_on channel=0 note=65 velocity=0 time=0.2769231
# 14.131469709090902 / 14.771504727272726 -> 0.88041612914526
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.012587413636363636
# 14.139861318181811 / 14.771504727272726 -> 0.8803451173454651
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0.00839160909090909
# 14.139861318181811 / 14.771504727272726 -> 0.8803451173454651
# scaling vel by 0.000 of msg note_on channel=0 note=62 velocity=0 time=0
# 14.257343845454539 / 14.771504727272726 -> 0.8793509521483354
# scaling vel by 0.000 of msg note_on channel=0 note=59 velocity=0 time=0.11748252727272726
# 14.274127063636357 / 14.771504727272726 -> 0.8792089285487454
# scaling vel by 0.000 of msg note_on channel=0 note=65 velocity=0 time=0.01678321818181818
# 14.303497695454539 / 14.771504727272726 -> 0.878960387249463
# scaling vel by 0.000 of msg note_on channel=0 note=56 velocity=0 time=0.029370631818181815
# 14.408392809090902 / 14.771504727272726 -> 0.8780727397520258
# scaling vel by 0.000 of msg note_on channel=0 note=52 velocity=0 time=0.10489511363636363
# 14.408392809090902 / 14.771504727272726 -> 0.8780727397520258
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0
# 14.408392809090902 / 14.771504727272726 -> 0.8780727397520258
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0
# 14.420980222727266 / 14.771504727272726 -> 0.8779662220523333
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0.012587413636363636
# 14.488113095454539 / 14.771504727272726 -> 0.8773981276539735
# scaling vel by 0.000 of msg note_on channel=0 note=62 velocity=0 time=0.06713287272727272
# 14.52587533636363 / 14.771504727272726 -> 0.8770785745548961
# scaling vel by 0.000 of msg note_on channel=0 note=60 velocity=0 time=0.03776224090909091
# 14.534266945454538 / 14.771504727272726 -> 0.8770075627551012
# scaling vel by 0.000 of msg note_on channel=0 note=40 velocity=0 time=0.00839160909090909
# 14.542658554545447 / 14.771504727272726 -> 0.8769365509553062
# scaling vel by 0.000 of msg note_on channel=0 note=57 velocity=0 time=0.00839160909090909
# 14.555245968181811 / 14.771504727272726 -> 0.8768300332556137
# scaling vel by 0.000 of msg note_on channel=0 note=64 velocity=0 time=0.012587413636363636
# 14.735665563636356 / 14.771504727272726 -> 0.8753032795600217
# scaling vel by 0.000 of msg note_on channel=0 note=33 velocity=0 time=0.18041959545454545
# 14.765036195454538 / 14.771504727272726 -> 0.8750547382607393
# scaling vel by 0.000 of msg note_on channel=0 note=33 velocity=0 time=0.029370631818181815

# %%
def scale_vels(midi_data: pretty_midi.PrettyMIDI, scale_factor: float = 1.0):
    """
    Scales the velocities of all notes in a MIDI file by a set amount, with the results capped at 127.

    Args:
        midi_data (pretty_midi.PrettyMIDI): The MIDI file data to be modified.
        scale_factor (float): The factor by which to scale the velocities. A value of 1.0 leaves velocities unchanged,
                            0.5 halves them, etc.
    """
    for instrument in midi_data.instruments:
        for note in instrument.notes:
            new_velocity = int(note.velocity * scale_factor)
            note.velocity = min(new_velocity, 127)

    return midi_data


with mido.open_output("to Max 1") as output:
    for message in mido.MidiFile(os.path.join(raw_dir, files[0])).play():
        output.send(message)

    time.sleep(1)
    scaled_midi =

# %%
def get_velocities(midi_data):
    """
    Analyzes MIDI file velocities.

    Args:
        midi_data (pretty_midi.PrettyMIDI): The MIDI file data.

    Returns:
        (list, list): A 2-element list containing the lowest and highest note velocities,
                    and a list of counts of note velocities broken into 10 bins.
    """
    velocities = []

    for instrument in midi_data.instruments:
        for note in instrument.notes:
            velocities.append(note.velocity)

    if velocities:
        lowest_velocity = min(velocities)
        highest_velocity = max(velocities)
    else:
        lowest_velocity, highest_velocity = 0, 0

    bin_counts, _ = np.histogram(velocities, bins=10, range=(1, 127))

    return [[lowest_velocity, highest_velocity], bin_counts.tolist()]

# %%
def scale_midi(midi_data, scale_factor):
    """
    Scales the velocities of all notes in a MIDI file by a set amount, with the results capped at 127.

    Args:
        midi_data (pretty_midi.PrettyMIDI): The MIDI file data to be modified.
        scale_factor (float): The factor by which to scale the velocities. A value of 1.0 leaves velocities unchanged,
                            0.5 halves them, etc.
    """
    for instrument in midi_data.instruments:
        for note in instrument.notes:
            new_velocity = int(note.velocity * scale_factor)
            note.velocity = min(new_velocity, 127)

    return midi_data

# %%
factor = 0.25

with mido.open_output("Disklavier") as output:
    for file in files:
        factor = np.random.uniform(0.1, 2.0)
        print(f"scaling by {factor}")
        midi = pretty_midi.PrettyMIDI(os.path.join(raw_dir, file))
        [[v_min, v_max], v_hist] = get_velocities(midi)
        print(f"playing '{file}' ({v_min}, {v_max})")
        print(v_hist)

        for msg in mido.MidiFile(os.path.join(raw_dir, file)).play():
            output.send(msg)

        new_path = os.path.join("..", "outputs", "graveyard", file)
        midi_scaled = scale_midi(midi, factor)
        midi_scaled.write(new_path)

        [[v_min, v_max], v_hist] = get_velocities(midi_scaled)
        print(f"playing '{file}' ({v_min}, {v_max})")
        print(v_hist)

        for msg in mido.MidiFile(new_path).play():
            output.send(msg)
# Out:
# scaling by 0.6571653525723734
# playing '20231227-080-02_0084-0096_n00.mid' (40, 71)
# [0, 0, 0, 29, 13, 7, 0, 0, 0, 0]
# playing '20231227-080-02_0084-0096_n00.mid' (26, 46)
# [0, 2, 40, 7, 0, 0, 0, 0, 0, 0]
# scaling by 1.991957028007091
# playing '20240117-064-05_0060-0075_d03.mid' (29, 80)
# [0, 0, 3, 12, 29, 4, 1, 0, 0, 0]
# playing '20240117-064-05_0060-0075_d03.mid' (57, 127)
# [0, 0, 0, 0, 2, 1, 2, 10, 20, 14]
# scaling by 1.339078714126342
# playing '20240122-055-01_0174-0192_u04.mid' (21, 83)
# [0, 1, 0, 7, 14, 26, 9, 0, 0, 0]
# playing '20240122-055-01_0174-0192_u04.mid' (28, 111)
# [0, 0, 1, 0, 2, 8, 20, 17, 9, 0]
# scaling by 1.2094521369003906
# playing '20240213-100-03_0220-0230_u02.mid' (13, 83)
# [1, 1, 5, 16, 15, 6, 1, 0, 0, 0]
# playing '20240213-100-03_0220-0230_u02.mid' (15, 100)
# [0, 2, 1, 8, 13, 14, 4, 3, 0, 0]
# scaling by 1.1860603808164492
# playing '20240227-076-02_0101-0113_d04.mid' (61, 93)
# [0, 0, 0, 0, 1, 17, 81, 2, 0, 0]
# playing '20240227-076-02_0101-0113_d04.mid' (72, 110)
# [0, 0, 0, 0, 0, 2, 14, 73, 12, 0]
# scaling by 1.4980753222301686
# playing '20240122-055-03_0000-0017_d03.mid' (28, 84)
# [0, 0, 1, 9, 38, 21, 5, 0, 0, 0]
# playing '20240122-055-03_0000-0017_d03.mid' (41, 125)
# [0, 0, 0, 1, 1, 8, 28, 24, 7, 5]
# scaling by 1.8534723125339343
# playing '20240227-076-01_0404-0416_d06.mid' (5, 91)
# [1, 0, 2, 9, 37, 30, 2, 1, 0, 0]
# playing '20240227-076-01_0404-0416_d06.mid' (9, 127)
# [1, 0, 0, 0, 1, 2, 5, 13, 22, 38]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 26
#      23 print(f"playing '{file}' ({v_min}, {v_max})")
#      24 print(v_hist)
# ---> 26 for msg in mido.MidiFile(new_path).play():
#      27     output.send(msg)
#
# File ~/Documents/Programming/disklavier/.venv/lib/python3.12/site-packages/mido/midifiles/midifiles.py:433, in MidiFile.play(self, meta_messages, now)
#     430 duration_to_next_event = input_time - playback_time
#     432 if duration_to_next_event > 0.0:
# --> 433     time.sleep(duration_to_next_event)
#     435 if isinstance(msg, MetaMessage) and not meta_messages:
#     436     continue
#
# KeyboardInterrupt:
