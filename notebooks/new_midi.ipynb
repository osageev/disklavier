# %%
import os
import mido
import librosa
import librosa.display

# %%
# Load the audio file
filename = "../data/datasets/raw audio/20240227-76-01.aif"
y, sr = librosa.load(filename)

# Detect onsets
onset_frames = librosa.onset.onset_detect(y=y, sr=sr, units="frames")
onset_times = librosa.frames_to_time(onset_frames, sr=sr)

list(onset_times)
# Out:
# [0.06965986394557823,
#  1.1609977324263039,
#  1.5789569160997732,
#  1.7182766439909296,
#  1.8808163265306121,
#  2.043356009070295,
#  2.182675736961451,
#  4.4117913832199545,
#  4.922630385487528,
#  4.96907029478458,
#  5.131609977324263,
#  5.340589569160998,
#  5.526349206349207,
#  5.712108843537415,
#  9.543401360544218,
#  10.332879818594105,
#  11.122358276643991,
#  11.911836734693878,
#  12.445895691609977,
#  12.701315192743763,
#  13.49079365079365,
#  14.117732426303855,
#  14.280272108843537,
#  15.069750566893424,
#  15.85922902494331,
#  16.648707482993196,
#  17.252426303854875,
#  17.438185941043084,
#  18.22766439909297,
#  18.83138321995465,
#  19.017142857142858,
#  19.806621315192743,
#  20.387120181405894,
#  20.59609977324263,
#  21.385578231292516,
#  21.966077097505668,
#  22.175056689342405,
#  22.96453514739229,
#  23.54503401360544,
#  23.754013605442175,
#  24.543492063492064,
#  25.14721088435374,
#  25.33297052154195,
#  26.122448979591837,
# ...

# %%
ds_path = os.path.join("..", "data", "datasets", "trimmed midi")
"data/outputs/tmp/20240123-70-03_0128-0136.mid"

file = os.listdir(ds_path)[0]
midi = mido.MidiFile("../data/outputs/tmp/20240213-100-04_0016-0024.mid")
midi.print_tracks()
# with mido.open_output("to Max 1") as output:
#     for msg in midi.play(True):
#         output.send(msg)
# Out:
# === Track 0
# MetaMessage('set_tempo', tempo=500000, time=0)
# MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0)
# MetaMessage('end_of_track', time=1)
# === Track 1
# Message('program_change', channel=0, program=0, time=0)
# Message('note_on', channel=0, note=49, velocity=46, time=3)
# Message('note_on', channel=0, note=68, velocity=68, time=11)
# Message('note_on', channel=0, note=80, velocity=63, time=0)
# Message('note_on', channel=0, note=78, velocity=66, time=13)
# Message('note_on', channel=0, note=78, velocity=0, time=29)
# Message('note_on', channel=0, note=80, velocity=0, time=10)
# Message('note_on', channel=0, note=68, velocity=0, time=27)
# Message('note_on', channel=0, note=76, velocity=62, time=79)
# Message('note_on', channel=0, note=73, velocity=51, time=6)
# Message('note_on', channel=0, note=73, velocity=0, time=32)
# Message('note_on', channel=0, note=49, velocity=0, time=3)
# ...
