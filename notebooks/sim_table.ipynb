# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
table_path = "../outputs/24-03-01/similarities.parquet"
simtable = pd.read_parquet(table_path)

# %%
simtable
# Out:
#       20240121-70-4-t_228-232.mid  20231227-80-6-t_132-136.mid  \
# 0                        1.000000                     0.508866
# 1                        0.508866                     1.000000
# 2                        0.675156                     0.726356
# 3                        0.961138                     0.569301
# 4                        0.363671                     0.824504
# ...                           ...                          ...
# 1399                     0.511076                     0.554734
# 1400                     0.634992                     0.375465
# 1401                     0.748298                     0.391476
# 1402                     0.745405                     0.484723
# 1403                     0.690631                     0.442088
#
#       20240121-70-8-t_020-024.mid  20240117-64-4-t_148-152.mid  \
# 0                        0.675156                     0.961138
# 1                        0.726356                     0.569301
# ...

# %%
nl = simtable['20240121-70-4-t_228-232.mid'].nlargest(5)
simtable.columns[nl.index[0]]
# Out:
# '20240121-70-4-t_228-232.mid'
