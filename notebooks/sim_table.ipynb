# %%
import pandas as pd
import os

# %%
table_path = "../outputs/all-fourbar-tmp.parquet"
simtable = pd.read_parquet(table_path)

# %%
simtable
# Out:
#                                                              0.20000  \
# rows
# 20240124-064-02_0585-0600_n00.mid  20240124-064-02_0585-0600_n00.mid
# 20240123-070-04_0109-0123_u06.mid  20240123-070-04_0109-0123_u06.mid
# 20240122-055-05_0139-0157_d01.mid  20240122-055-05_0139-0157_d01.mid
# 20240213-100-05_0297-0307_d02.mid  20240213-100-05_0297-0307_d02.mid
# 20240121-070-03_0000-0013_d01.mid  20240121-070-03_0000-0013_d01.mid
# ...                                                              ...
# 20240123-070-05_0041-0054_d05.mid  20240123-070-05_0027-0041_d05.mid
# 20240227-076-01_0075-0088_d05.mid  20240227-076-01_0063-0075_d05.mid
# 20240121-070-02_0740-0754_u05.mid  20240121-070-02_0726-0740_d05.mid
# 20240124-064-02_0555-0570_u03.mid  20240124-064-02_0540-0555_u03.mid
# 20231228-072-01_0000-0013_d02.mid  20231228-072-01_0013-0026_n00.mid
#
#                                       sim-1  \
# rows
# 20240124-064-02_0585-0600_n00.mid  1.000000
# ...

# %%
simtable.loc["20240213-100-06_0585-0595_u01.mid"]
# Out:
# 0.20000    20240213-100-06_0576-0585_d04.mid
# sim-1                               0.644969
# 0.36667    20240213-100-06_0576-0585_u01.mid
# sim-2                               0.626654
# 0.53333    20240213-100-06_0595-0604_u01.mid
# sim-3                               0.992846
# 0.63333    20240213-100-06_0566-0576_u01.mid
# sim-4                               0.990518
# 0.73333    20240213-100-06_0604-0614_u01.mid
# sim-5                                    1.0
# 0.78663    20240213-100-06_0566-0576_u01.mid
# sim-6                               0.991657
# 0.83993    20240213-100-06_0556-0566_u01.mid
# sim-7                                0.98956
# 0.89323    20240213-100-06_0739-0748_u01.mid
# sim-8                               0.989774
# 0.94653    20240213-100-06_0604-0614_u01.mid
# sim-9                               0.986217
# 1.00000    20240213-100-06_0614-0624_u01.mid
# sim-10                              0.995206
# Name: 20240213-100-06_0585-0595_u01.mid, dtype: object
